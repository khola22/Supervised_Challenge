# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import ast

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight


from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.cluster import KMeans

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sentence_transformers import SentenceTransformer

from helper import plot_missing_values, replace_ids_with_titles

# %%
# Import the datasets 
tracks_echonest = pd.read_csv('data/tracks_echonest_titles.tsv', sep='\t')
tracks_spectral = pd.read_csv('data/tracks_spectral_titles.tsv', sep='\t')
genres = pd.read_csv('data/genres.csv', sep=',')

# tracks_spectral['genres'] = tracks_spectral['genres'].apply(ast.literal_eval)
# tracks_spectral['genres_all'] = tracks_spectral['genres_all'].apply(ast.literal_eval)
# # transfor genre ids to titles
# tracks_spectral = replace_ids_with_titles(tracks_spectral, 'genre_top', genres)
# tracks_spectral = replace_ids_with_titles(tracks_spectral, 'genres', genres)
# tracks_spectral = replace_ids_with_titles(tracks_spectral, 'genres_all', genres)

# %%
# Plot missing values in both datasets
datasets = {
    'Echonest Features': tracks_echonest,
    'Spectral Features Reduced': tracks_spectral
}

plot_missing_values(datasets)
# Out:
# c:\Users\Chaima\Documents_local\3A\Supervised_Challenge\helper.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=na_pct.values, y=na_pct.index, palette='viridis')

# %%
# remove missing values from tracks_echonest
df_spectral = tracks_spectral
df_echonest = tracks_echonest.dropna()
datasets = {
    'Echonest Features Filled': df_echonest,
    'Spectral Features Reduced': tracks_spectral
}
plot_missing_values(datasets)

# %%
print(f"Feature titles in tracks_echonest : {tracks_echonest.columns.tolist()}")
# Out:
# Feature titles in tracks_echonest : ['track_id', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'tempo', 'valence', 'album_title', 'album_tracks', 'artist_latitude', 'artist_longitude', 'artist_name', 'duration', 'favorites', 'genre_top', 'genres', 'genres_all', 'interest', 'listens', 'title', 'spectral_bandwidth_kurtosis_01', 'spectral_bandwidth_max_01', 'spectral_bandwidth_mean_01', 'spectral_bandwidth_median_01', 'spectral_bandwidth_min_01', 'spectral_bandwidth_skew_01', 'spectral_bandwidth_std_01', 'spectral_centroid_kurtosis_01', 'spectral_centroid_max_01', 'spectral_centroid_mean_01', 'spectral_centroid_median_01', 'spectral_centroid_min_01', 'spectral_centroid_skew_01', 'spectral_centroid_std_01', 'spectral_rolloff_kurtosis_01', 'spectral_rolloff_max_01', 'spectral_rolloff_mean_01', 'spectral_rolloff_median_01', 'spectral_rolloff_min_01', 'spectral_rolloff_skew_01', 'spectral_rolloff_std_01', 'artist_location_unknown']

# %% [markdown]
# ## Feature Classification for Genre Prediction (Task 1 & 2)
#
# ### 1. ID / Join-Only Columns
# **Drop as predictors**
# - `track_id` — use only for merges; never include as a feature.
#
# ---
#
# ### 2. High-Cardinality Text
# **Drop for baseline; maybe use later with NLP**
# - `title`
# - `album_title`
# - `artist_name`
#
# (Too sparse/high-cardinality for simple audio-only baselines.)
#
# ---
#
# ### 3. Genre Labels / Taxonomy
# **Targets or auxiliary info (not numeric predictors)**
# - `genre_top` — **main target**
# - `genres`, `genres_all` — lists of tags; can be parsed or merged with `genres.csv` but raw strings are unusable as features.
#
# ---
#
# ### 4. Core Audio Predictors
# **Keep — main baseline features**
# - `acousticness`
# - `danceability`
# - `energy`
# - `instrumentalness`
# - `liveness`
# - `speechiness`
# - `tempo`
# - `valence`
# - `duration`
#
# (Standard “Spotify-like” features; strong predictors for genre.)
#
# ---
#
# ### 5. Popularity / Usage
# **Keep *only* if predicting popularity — otherwise drop (genre leakage risk)**
# - `favorites`
# - `interest`
# - `listens`
#
# (These often correlate with genre distribution → leakage.)
#
# ---
#
# ### 6. Location / Context
# **Optional (weak signal for pure audio genre)**
# - `artist_latitude`
# - `artist_longitude`
# - `artist_location_unknown`
# - `album_tracks`
#
# ---
#
# ### 7. Spectral Feature Block
# **Keep, but ideally reduce dimensionality**
# - All `spectral_bandwidth_*`
# - All `spectral_centroid_*`
# - All `spectral_rolloff_*`
#
# (Important for timbre/brightness but highly redundant → PCA or aggregation recommended.)
#
# ---
#
# ### ✔ Recommended Clean Baseline Feature Set
# For a strong yet simple **genre prediction baseline**:
# - The 8–9 Spotify-like audio features
# - `duration`
# - One location dummy (optional)
# - A **reduced set** of spectral features (via PCA or summary statistics)
# - **Drop** IDs, text fields, and popularity metrics

# %%
# Drop the ID columns
df_echonest = df_echonest.drop(columns=['track_id'])
df_spectral = df_spectral.drop(columns=['track_id'])

# Drop artist location related features
df_echonest = df_echonest.drop(columns=['artist_latitude', 'artist_longitude', 'artist_location_unknown'])
df_spectral = df_spectral.drop(columns=['artist_latitude', 'artist_longitude', 'artist_location_unknown'])

# %%
# We re going to inspect colinearity in these groups of features 
core_audio_features = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration']
spectral_features = [col for col in df_spectral.columns if col.startswith('spectral_')]
popularity_features = ['favorites', 'interest', 'listens']

print(f"Core audio features: {core_audio_features}")
print(f"Spectral features: {spectral_features}")
print(f"Popularity features: {popularity_features}")
# print the rest of features execpt the above three groups
other_features = [col for col in df_echonest.columns if col not in core_audio_features + spectral_features + popularity_features]
print(f"Other features in df_echonest: {other_features}")
other_features_spectral = [col for col in df_spectral.columns if col not in core_audio_features + spectral_features + popularity_features]
print(f"Other features in df_spectral: {other_features_spectral}")
# Out:
# Core audio features: ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration']
# Spectral features: ['spectral_bandwidth_kurtosis_01', 'spectral_bandwidth_max_01', 'spectral_bandwidth_mean_01', 'spectral_bandwidth_median_01', 'spectral_bandwidth_min_01', 'spectral_bandwidth_skew_01', 'spectral_bandwidth_std_01', 'spectral_centroid_kurtosis_01', 'spectral_centroid_max_01', 'spectral_centroid_mean_01', 'spectral_centroid_median_01', 'spectral_centroid_min_01', 'spectral_centroid_skew_01', 'spectral_centroid_std_01', 'spectral_rolloff_kurtosis_01', 'spectral_rolloff_max_01', 'spectral_rolloff_mean_01', 'spectral_rolloff_median_01', 'spectral_rolloff_min_01', 'spectral_rolloff_skew_01', 'spectral_rolloff_std_01']
# Popularity features: ['favorites', 'interest', 'listens']
# Other features in df_echonest: ['album_title', 'album_tracks', 'artist_name', 'genre_top', 'genres', 'genres_all', 'title']
# Other features in df_spectral: ['album_title', 'album_tracks', 'artist_name', 'genre_top', 'genres', 'genres_all', 'title']

# %%
def plot_feature_correlation(df, feature_list, title="Correlation Matrix"):
    """
    Plots a correlation matrix for a given list of features in a DataFrame.

    Parameters:
        df (pd.DataFrame): DataFrame containing the features.
        feature_list (list): List of column names to include in the correlation matrix.
        title (str): Title of the plot.
    """
    corr = df[feature_list].corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=False, fmt=".1f", cmap="coolwarm", square=True, linewidths=0.5)
    plt.title(title, fontsize=16)
    plt.show()

# %%
plot_feature_correlation(df_echonest, core_audio_features+spectral_features+popularity_features, title="Core Audio + Spectral + Popularity Features Correlation (Echonest Dataset)")
plot_feature_correlation(df_spectral, spectral_features+popularity_features, title="Core Audio + Popularity Features Correlation (Spectral Dataset)")

# %%
# We will use PCA on spectral features to reduce colinearity

def apply_pca(df, feature_list, n_components=None):
    """
    Applies PCA to a group of features.

    Parameters:
        df (pd.DataFrame): DataFrame containing the features.
        feature_list (list): List of columns to apply PCA on.
        n_components (int or None): Number of PCA components to keep. If None, keep all.

    Returns:
        pca (PCA object): Fitted PCA object.
        df_pca (pd.DataFrame): Transformed PCA components as DataFrame.
    """

    # strandardize the features before applying PCA
    scaler = StandardScaler()
    df[feature_list] = scaler.fit_transform(df[feature_list])
    
    pca = PCA(n_components=n_components)
    X = df[feature_list].values
    X_pca = pca.fit_transform(X)
    
    # Build a DataFrame with PCA components
    component_names = [f"PC{i+1}" for i in range(X_pca.shape[1])]
    df_pca = pd.DataFrame(X_pca, columns=component_names, index=df.index)
    
    return pca, df_pca

def plot_pca_correlations(df, feature_list, pca, df_pca, title="PCA vs Original Features Correlation"):
    """
    Plots correlation of each PCA component with the original features.

    Parameters:
        df (pd.DataFrame): Original DataFrame.
        feature_list (list): Original features used in PCA.
        pca (PCA object): Fitted PCA object.
        df_pca (pd.DataFrame): DataFrame containing PCA components.
        title (str): Title of the plot.
    """
    # Compute correlation of each PCA component with original features
    corr_matrix = pd.DataFrame(
        np.dot(df[feature_list].values.T, df_pca.values) / (len(df)-1),
        index=feature_list,
        columns=df_pca.columns
    )
    
    # Optional: normalize correlations between -1 and 1
    corr_matrix = corr_matrix / corr_matrix.abs().max()
    
    plt.figure(figsize=(12,8))
    sns.heatmap(corr_matrix, annot=False, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title(title, fontsize=16)
    plt.show()

def plot_pca_variance(pca, title="Explained Variance per PCA Component"):
    """
    Plots the explained variance ratio of each PCA component.

    Parameters:
        pca (PCA object): Fitted PCA object.
        title (str): Title of the plot.
    """
    explained_variance = pca.explained_variance_ratio_
    cumulative_variance = explained_variance.cumsum()
    
    plt.figure(figsize=(10,6))
    plt.bar(range(1, len(explained_variance)+1), explained_variance, alpha=0.6, label="Individual variance")
    plt.step(range(1, len(cumulative_variance)+1), cumulative_variance, where='mid', color='red', label="Cumulative variance")
    plt.xlabel("PCA Component")
    plt.ylabel("Explained Variance Ratio")
    plt.title(title, fontsize=16)
    plt.xticks(range(1, len(explained_variance)+1))
    plt.legend()
    plt.show()

# %%
pca_spectral, df_pca_spectral = apply_pca(df_spectral, spectral_features)
plot_pca_correlations(df_spectral, spectral_features, pca_spectral, df_pca_spectral, title="PCA Components vs Original Spectral Features Correlation")
plot_pca_variance(pca_spectral, title="Explained Variance by PCA Components (Spectral Features)")

# %%
# We re going to keep the 1st 5 PCA components and remove all spectral original features
n_pca_components = 5
df_spectral_pca = df_spectral.drop(columns=spectral_features)
df_echonest_pca = df_echonest.drop(columns=spectral_features)
for i in range(n_pca_components):
    df_spectral_pca[f'Spec_PC{i+1}'] = df_pca_spectral[f'PC{i+1}']
    df_echonest_pca[f'Spec_PC{i+1}'] = df_pca_spectral[f'PC{i+1}']

print(f"Spectral DataFrame shape after adding PCA components: {df_spectral_pca.shape}")
print(f"Spectral DataFrame features after adding PCA components: {df_spectral_pca.columns.tolist()}")
print(f"Echonest DataFrame shape after adding PCA components: {df_echonest_pca.shape}")
print(f"Echonest DataFrame features after adding PCA components: {df_echonest_pca.columns.tolist()}")
# Out:
# Spectral DataFrame shape after adding PCA components: (97288, 16)
# Spectral DataFrame features after adding PCA components: ['album_title', 'album_tracks', 'artist_name', 'duration', 'favorites', 'genre_top', 'genres', 'genres_all', 'interest', 'listens', 'title', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5']
# Echonest DataFrame shape after adding PCA components: (10405, 24)
# Echonest DataFrame features after adding PCA components: ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'tempo', 'valence', 'album_title', 'album_tracks', 'artist_name', 'duration', 'favorites', 'genre_top', 'genres', 'genres_all', 'interest', 'listens', 'title', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5']

# %%
# Apply PCA on popularity features as well 
pca_popularity, df_pca_popularity = apply_pca(df_spectral_pca, popularity_features)
plot_pca_correlations(df_spectral_pca, popularity_features, pca_popularity, df_pca_popularity, title="PCA Components vs Original Popularity Features Correlation")
plot_pca_variance(pca_popularity, title="Explained Variance by PCA Components (Popularity Features)")

# %%
# We are going to keep only the 1st pca component from popularity features
# for both datasets
n_popularity_pca_components = 1
df_spectral_final = df_spectral_pca.drop(columns=popularity_features)
df_echonest_final = df_echonest_pca.drop(columns=popularity_features)
for i in range(n_popularity_pca_components):
    df_spectral_final[f'Pop_PC{i+1}'] = df_pca_popularity[f'PC{i+1}']
    df_echonest_final[f'Pop_PC{i+1}'] = df_pca_popularity[f'PC{i+1}']

print(f"Spectral DataFrame shape after adding PCA components: {df_spectral_final.shape}")
print(f"Spectral DataFrame features after adding PCA components: {df_spectral_final.columns.tolist()}")
print(f"Echonest DataFrame shape after adding PCA components: {df_echonest_final.shape}")
print(f"Echonest DataFrame features after adding PCA components: {df_echonest_final.columns.tolist()}")
# Out:
# Spectral DataFrame shape after adding PCA components: (97288, 14)
# Spectral DataFrame features after adding PCA components: ['album_title', 'album_tracks', 'artist_name', 'duration', 'genre_top', 'genres', 'genres_all', 'title', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']
# Echonest DataFrame shape after adding PCA components: (10405, 22)
# Echonest DataFrame features after adding PCA components: ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'tempo', 'valence', 'album_title', 'album_tracks', 'artist_name', 'duration', 'genre_top', 'genres', 'genres_all', 'title', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']

# %%
# We re going to drop genres and genres_all because they re leakage features
# We re dropping them for the preprocessing 
df_spectral_final = df_spectral_final.drop(columns=['genres', 'genres_all'])
df_echonest_final = df_echonest_final.drop(columns=['genres', 'genres_all'])

print(f"Final DataFrame shape (Spectral): {df_spectral_final.shape}")
print(f"Final Dataframe features (Spectral): {df_spectral_final.columns.tolist()}")
print(f"Final DataFrame shape (Echonest): {df_echonest_final.shape}")
print(f"Final Dataframe features (Echonest): {df_echonest_final.columns.tolist()}")
# Out:
# Final DataFrame shape (Spectral): (97288, 12)
# Final Dataframe features (Spectral): ['album_title', 'album_tracks', 'artist_name', 'duration', 'genre_top', 'title', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']
# Final DataFrame shape (Echonest): (10405, 20)
# Final Dataframe features (Echonest): ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'tempo', 'valence', 'album_title', 'album_tracks', 'artist_name', 'duration', 'genre_top', 'title', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']

# %% [markdown]
# We re going to try embedding on textual data

# %%
# Now we will use embeddings for the text features (artist_name, title, album_name)
text_features = ['artist_name', 'title', 'album_title']

df_embeddings = df_echonest_final.copy()

# Concatenate into one string per track
df_embeddings["text_meta"] = (
    df_embeddings["artist_name"].fillna("") + " - " +
    df_embeddings["title"].fillna("") + " | " +
    df_embeddings["album_title"].fillna("")
)

# Lowercase and strip whitespace
df_embeddings["text_meta"] = df_embeddings["text_meta"].str.lower().str.strip()

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

texts = df_embeddings["text_meta"].tolist()

# Encode in batches
batch_size = 512
all_embeds = []
for i in range(0, len(texts), batch_size):
    batch_texts = texts[i:i+batch_size]
    batch_embeds = model.encode(batch_texts, show_progress_bar=True, convert_to_numpy=True)
    all_embeds.extend(batch_embeds)

# Now text_embs[i] is the embedding for track i.
text_embs = np.vstack(all_embeds)
# Out:
# Batches: 100%|██████████| 16/16 [00:06<00:00,  2.45it/s]
# Batches: 100%|██████████| 16/16 [00:04<00:00,  3.88it/s]
# Batches: 100%|██████████| 16/16 [00:04<00:00,  3.81it/s]
# Batches: 100%|██████████| 16/16 [00:05<00:00,  2.76it/s]
# Batches: 100%|██████████| 16/16 [00:05<00:00,  2.95it/s]
# Batches: 100%|██████████| 16/16 [00:05<00:00,  2.95it/s]
# Batches: 100%|██████████| 16/16 [00:07<00:00,  2.16it/s]
# Batches: 100%|██████████| 16/16 [00:08<00:00,  1.89it/s]
# Batches: 100%|██████████| 16/16 [00:08<00:00,  1.88it/s]
# Batches: 100%|██████████| 16/16 [00:10<00:00,  1.47it/s]
# Batches: 100%|██████████| 16/16 [00:12<00:00,  1.29it/s]
# Batches: 100%|██████████| 16/16 [00:17<00:00,  1.11s/it]
# Batches: 100%|██████████| 16/16 [00:12<00:00,  1.24it/s]
# Batches: 100%|██████████| 16/16 [00:12<00:00,  1.26it/s]
# Batches: 100%|██████████| 16/16 [00:10<00:00,  1.48it/s]
# Batches: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# Batches: 100%|██████████| 16/16 [00:15<00:00,  1.03it/s]
# Batches: 100%|██████████| 16/16 [00:11<00:00,  1.38it/s]
# Batches: 100%|██████████| 16/16 [00:07<00:00,  2.06it/s]
# Batches: 100%|██████████| 16/16 [00:08<00:00,  1.93it/s]
# Batches: 100%|██████████| 6/6 [00:02<00:00,  2.42it/s]

# %%
text_embs.shape  # (num_tracks, embedding_dimension)
# Out:
# (10405, 384)

# %%
text_embs_pd = pd.DataFrame(text_embs)
text_embs_pd.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.064493  0.040722  0.019638  0.058853 -0.006592  0.061206  0.003427
# 1  0.047659 -0.005769  0.015794  0.067692 -0.011705  0.033822  0.021273
# 2  0.082888  0.034695 -0.001763  0.010147 -0.053025  0.041640 -0.058108
# 3  0.009422 -0.023726  0.018944  0.025754 -0.008091  0.053894 -0.002441
# 4  0.007854 -0.054865  0.030726  0.012789 -0.000792  0.069638  0.029039
#
#         7         8         9    ...       374       375       376       377  \
# 0 -0.121171 -0.011342  0.013000  ...  0.029383 -0.045956 -0.072811  0.087778
# 1 -0.135541 -0.001400  0.008527  ... -0.002746 -0.055737 -0.060171  0.070429
# 2 -0.084850 -0.037530 -0.009622  ... -0.006076 -0.030518  0.016997  0.037393
# 3 -0.059583 -0.019687 -0.016590  ...  0.012782  0.023717 -0.023621 -0.001498
# 4 -0.096973 -0.028759 -0.024760  ...  0.052589  0.003238 -0.097681  0.056844
#
#         378       379       380       381       382       383
# 0 -0.038365  0.023333  0.103026  0.025474  0.043048  0.013123
# 1 -0.004351  0.031436  0.095005  0.025266  0.070416  0.039543
# 2  0.045892  0.019554  0.095097 -0.005180  0.043385  0.016198
# 3 -0.047580  0.023265  0.073796  0.013045 -0.000760  0.032979
# 4 -0.052756 -0.001094  0.123207  0.017641 -0.030052  0.029991
#
# [5 rows x 384 columns]

# %%
# Apply PCA on text embeddings to reduce dimensionality and plot correlations
pca_text, df_pca_text = apply_pca(pd.DataFrame(text_embs), list(range(text_embs.shape[1])), n_components=100)
plot_pca_correlations(pd.DataFrame(text_embs), list(range(text_embs.shape[1])), pca_text, df_pca_text, title="PCA vs Text Embeddings Correlation")
plot_pca_variance(pca_text, title="Explained Variance by PCA Components (Text Embeddings)")

# %% [markdown]
# We noticed that we need + 100 feature to have an embedding of the artist and track textual features, which is not helpful, therefore we're going to drop thse feature

# %%
# Drop original text features from df_spectral_final
df_spectral_final = df_spectral_final.drop(columns=text_features)
df_echonest_final = df_echonest_final.drop(columns=text_features)

print(f"Final DataFrame shape (Spectral): {df_spectral_final.shape}")
print(f"Final Dataframe features (Spectral): {df_spectral_final.columns.tolist()}")
print(f"Final DataFrame shape (Echonest): {df_echonest_final.shape}")
print(f"Final Dataframe features (Echonest): {df_echonest_final.columns.tolist()}")
# Out:
# Final DataFrame shape (Spectral): (97288, 9)
# Final Dataframe features (Spectral): ['album_tracks', 'duration', 'genre_top', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']
# Final DataFrame shape (Echonest): (10405, 17)
# Final Dataframe features (Echonest): ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'tempo', 'valence', 'album_tracks', 'duration', 'genre_top', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']

# %% [markdown]
# The clustering (K-means)

# %%
# Drop genre_top for clustering
df_spectral_num = df_spectral_final.drop(columns=['genre_top'])
df_echonest_num = df_echonest_final.drop(columns=['genre_top'])

# %% [markdown]
# Approach 1 (echonest dataset): [Bad clustering n1]

# %%
# We re going to use encoder features for the echonest dataset to reduce dimensionality
encoder_features = ['acousticness', 'danceability', 'energy', 'instrumentalness',
    'liveness', 'speechiness', 'tempo', 'valence',
    'album_tracks', 'duration',
    'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5',
    'Pop_PC1']

X = df_echonest_num[encoder_features].values

# Standarize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
input_dim = X_scaled.shape[1]

# %%
# Hyperparameters
encoding_dim = 10
hidden_dim = 24
epochs = 30
batch_size = 256

# encoder
input_layer = layers.Input(shape=(input_dim,))

h = layers.Dense(hidden_dim, activation='relu')(input_layer)

botteleneck = layers.Dense(encoding_dim, activation='relu')(h)

# decoder
h_dec = layers.Dense(hidden_dim, activation='relu')(botteleneck)
output_layer = layers.Dense(input_dim, activation='linear')(h_dec)
# autoencoder models
autoencoder = models.Model(inputs=input_layer, outputs=output_layer)
autoencoder.compile(optimizer='adam', loss='mse')

# Train
history = autoencoder.fit(X_scaled, X_scaled,
                          epochs=epochs,
                          batch_size=batch_size,
                          shuffle=True,
                          validation_split=0.1,
                          verbose=1)
# Out:
# Epoch 1/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 1.0096 - val_loss: 0.8143
# Epoch 2/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9312 - val_loss: 0.7489
# Epoch 3/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8226 - val_loss: 0.6539
# Epoch 4/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7078 - val_loss: 0.5791
# Epoch 5/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6236 - val_loss: 0.5243
# Epoch 6/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5635 - val_loss: 0.4866
# Epoch 7/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5157 - val_loss: 0.4543
# Epoch 8/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4749 - val_loss: 0.4236
# Epoch 9/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4395 - val_loss: 0.4037
# Epoch 10/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4104 - val_loss: 0.3835
# Epoch 11/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3855 - val_loss: 0.3625
# Epoch 12/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3635 - val_loss: 0.3472
# Epoch 13/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3427 - val_loss: 0.3284
# Epoch 14/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3219 - val_loss: 0.3060
# Epoch 15/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2996 - val_loss: 0.2883
# Epoch 16/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2820 - val_loss: 0.2756
# Epoch 17/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2697 - val_loss: 0.2746
# Epoch 18/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2598 - val_loss: 0.2712
# Epoch 19/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2520 - val_loss: 0.2586
# Epoch 20/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2450 - val_loss: 0.2485
# Epoch 21/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2391 - val_loss: 0.2469
# Epoch 22/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2325 - val_loss: 0.2372
# Epoch 23/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2275 - val_loss: 0.2353
# Epoch 24/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2217 - val_loss: 0.2382
# Epoch 25/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2171 - val_loss: 0.2178
# Epoch 26/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2119 - val_loss: 0.2187
# Epoch 27/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2070 - val_loss: 0.2067
# Epoch 28/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2016 - val_loss: 0.2064
# Epoch 29/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1964 - val_loss: 0.1980
# Epoch 30/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1915 - val_loss: 0.1895

# %%
encoder = models.Model(inputs=input_layer, outputs=botteleneck)

# Get the encoded representations
Z = encoder.predict(X_scaled, batch_size=batch_size)
z_scaler = StandardScaler()
Z_scaled = z_scaler.fit_transform(Z)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# We are going to run kmeans on latent space and assign cluster labels
# 1st we try out 3 clusters
k = 3
k_means_ae = KMeans(n_clusters=k, random_state=42)
cluster_labels_ae = k_means_ae.fit_predict(Z_scaled)

df_echonest_ae = df_echonest_final.copy()
df_echonest_ae['cluster_ae'] = cluster_labels_ae

# See which fine genres fall in which AE-cluster
ct = pd.crosstab(df_echonest_ae['cluster_ae'], df_echonest_ae['genre_top'])
ct
# Out:
# genre_top   Blues  Classical  Easy Listening  Electronic  Experimental  Folk  \
# cluster_ae
# 0              69         93              12         733            17   409
# 1               4         39               1          52             0    30
# 2              91        171              45        2063            36   773
#
# genre_top   Hip-Hop  Instrumental  International  Jazz  Pop  Rock
# cluster_ae
# 0               499            37             88   151  284   910
# 1                15             4              1     9   25    56
# 2               389            78            180   286  717  2038

# %%
ct.plot(kind='bar', stacked=True, figsize=(8,5))
plt.xlabel('Autoencoder cluster')
plt.ylabel('Count of tracks')
plt.title('genre_top distribution inside AE clusters')
plt.tight_layout()
plt.show()

# %%
# 1) Mean feature per cluster
mean_by_cluster = df_echonest_ae.groupby('cluster_ae')[
    ['acousticness','danceability','energy','instrumentalness',
     'liveness','speechiness','tempo','valence']
].mean()

mean_by_cluster.T.plot(kind='bar', figsize=(8,4))
plt.ylabel('Mean value')
plt.title('Mean musical features per AE cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# Approach 2 : Clustering without autoencoding (echonest dataset) [bad approach]

# %%
df_echonest_final.head()
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  \
# 0      0.373039      0.429892  0.645929          0.769285  0.195042
# 1      0.908215      0.427918  0.694364          0.950413  0.269082
# 2      0.204111      0.501329  0.608690          0.725811  0.125451
# 3      0.464478      0.419687  0.743163          0.786033  0.214622
# 4      0.921960      0.350383  0.588584          0.861204  0.120561
#
#    speechiness    tempo   valence  album_tracks  duration genre_top  Spec_PC1  \
# 0     0.101240  159.908  0.474554            10       131   Hip-Hop  0.118641
# 1     0.180927  188.077  0.585049            10       185   Hip-Hop  0.196037
# 2     0.623711  137.676  0.522381            10       183   Hip-Hop  1.123142
# 3     0.142762   79.371  0.644394            10       213   Hip-Hop  0.707095
# 4     0.187306  190.518  0.537996            10       162   Hip-Hop  0.450496
#
#    Spec_PC2  Spec_PC3  Spec_PC4  Spec_PC5   Pop_PC1
# 0  1.163968 -0.037856  0.976482  0.449219 -0.373249
# 1 -0.143670 -0.278785  0.588802  0.068307 -0.369163
# 2  0.154781 -0.490849 -0.376471 -0.140204 -0.372563
# 3 -0.136350 -0.154662  0.554418 -0.467090 -0.241591
# 4 -1.025226  0.646793  1.410960 -0.149837 -0.371245

# %%
# We re going to try not encoding echonest features and use all features in the dataset
df_echonest_kmeans = df_echonest_final.copy()
X = df_echonest_kmeans.drop(columns=['genre_top']).values

kmeans = KMeans(n_clusters=3, random_state=42)
cluster_labels = kmeans.fit_predict(X)


df_echonest_kmeans['cluster_kmeans'] = cluster_labels

# See which fine genres fall in which KMeans-cluster
ct_kmeans = pd.crosstab(df_echonest_kmeans['cluster_kmeans'], df_echonest_kmeans['genre_top'])
ct_kmeans.plot(kind='bar', stacked=True, figsize=(8,5))
plt.xlabel('KMeans cluster')
plt.ylabel('Count of tracks')
plt.title('genre_top distribution inside KMeans clusters')
plt.tight_layout()
plt.show()

# %%
# 1) Mean feature per cluster
mean_by_cluster = df_echonest_kmeans.groupby('cluster_kmeans')[
    ['acousticness','danceability','energy','instrumentalness',
     'liveness','speechiness','tempo','valence']
].mean()

mean_by_cluster.T.plot(kind='bar', figsize=(8,4))
plt.ylabel('Mean value')
plt.title('Mean musical features per KMeans cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# Approach 3 : transform lines into genres instead of tracks (echonest dataset)

# %%
num_cols = [
    'acousticness','danceability','energy','instrumentalness',
    'liveness','speechiness','tempo','valence',
    'album_tracks','duration',
    'Spec_PC1','Spec_PC2','Spec_PC3','Spec_PC4','Spec_PC5',
    'Pop_PC1'
]

# Compute mean features per genre_top
genre_df = df_echonest_final.groupby('genre_top')[num_cols].median().reset_index()

# 4) 25th percentile per genre
# genre_df = df_echonest_final.groupby('genre_top')[num_cols].quantile(0.25).reset_index()

# remove the features with low variance
var_series = genre_df[num_cols].var()   # variance of each column

print(var_series.sort_values())
# Out:
# liveness              0.000057
# Pop_PC1               0.001010
# speechiness           0.001271
# danceability          0.010501
# Spec_PC5              0.015487
# Spec_PC3              0.016149
# valence               0.025924
# energy                0.032630
# Spec_PC4              0.038216
# Spec_PC2              0.047736
# acousticness          0.067746
# instrumentalness      0.089786
# Spec_PC1              0.305490
# album_tracks         20.628788
# tempo                74.100680
# duration            736.992424
# dtype: float64

# %%
selector = VarianceThreshold(threshold=0.01)  # choose threshold
X_lowvar = selector.fit_transform(genre_df[num_cols])

# Get kept column names
kept_cols = genre_df[num_cols].columns[selector.get_support()]

# print kept columns
print("Kept columns after low variance removal:")
for col in kept_cols:
    print(col)
# Out:
# Kept columns after low variance removal:
# acousticness
# energy
# instrumentalness
# tempo
# valence
# album_tracks
# duration
# Spec_PC1
# Spec_PC2
# Spec_PC3
# Spec_PC4
# Spec_PC5

# %%
# Separate key and features
Xg = genre_df[kept_cols].values

scaler_g = StandardScaler()
Xg_scaled = scaler_g.fit_transform(Xg)

kmeans_genre = KMeans(n_clusters=4, random_state=42)
genre_cluster_labels = kmeans_genre.fit_predict(Xg_scaled)

genre_df['genre_cluster'] = genre_cluster_labels

# %%
genre_df.head()
# Out:
#         genre_top  acousticness  danceability    energy  instrumentalness  \
# 0           Blues      0.797929      0.530396  0.408815          0.083035
# 1       Classical      0.993000      0.326449  0.054979          0.899458
# 2  Easy Listening      0.723953      0.591393  0.502951          0.867415
# 3      Electronic      0.174973      0.628130  0.645337          0.863792
# 4    Experimental      0.863719      0.368907  0.286872          0.839526
#
#    liveness  speechiness     tempo   valence  album_tracks  duration  \
# 0  0.123691     0.040514  111.4770  0.554266          10.0     232.5
# 1  0.115801     0.046699   96.2100  0.172912          16.0     211.0
# 2  0.108289     0.052036  113.2605  0.420312          21.0     195.5
# 3  0.112875     0.062551  122.8650  0.440494          11.0     234.5
# 4  0.114213     0.046528  108.0120  0.141975          11.0     238.0
#
#    Spec_PC1  Spec_PC2  Spec_PC3  Spec_PC4  Spec_PC5   Pop_PC1  genre_cluster
# 0  0.138550 -0.316360 -0.452661 -0.022216 -0.093704 -0.273824              2
# 1  0.749898 -0.040486 -0.102062 -0.303287 -0.196854 -0.247017              0
# 2 -0.848339 -0.602880 -0.327029  0.244039 -0.268333 -0.211892              1
# 3  0.179839 -0.136229 -0.217867 -0.050462 -0.175179 -0.281949              1
# 4  1.503639  0.004996 -0.017093 -0.486920 -0.593166 -0.341985              0

# %%
# Which genres in each cluster?
for c in sorted(genre_df['genre_cluster'].unique()):
    print(f"\nCluster {c}:")
    print(genre_df.loc[genre_df['genre_cluster'] == c, 'genre_top'].tolist())
# Out:
# Cluster 0:
# ['Classical', 'Experimental']
#
# Cluster 1:
# ['Easy Listening', 'Electronic', 'Folk', 'Hip-Hop', 'International', 'Pop', 'Rock']
#
# Cluster 2:
# ['Blues', 'Jazz']
#
# Cluster 3:
# ['Instrumental']

# %% [markdown]
# The current clustering is the best, we can adjust it a little bit in it using expert knowledge and gather cluster 2 and 3 in one custer, and we are going to move easy listening and folk from cluster 1 to equalize a little bit the number of genres in each cluster :
#
# Group A – Mainstream & Beat‑driven
#     Electronic, Hip-Hop, Pop, Rock, International
#     (high/medium energy, more rhythmic)
#
# Group B – Jazz/Blues/Instrumental/Easy listening
#     Jazz, Blues, Instrumental, Easy Listening
#     (smoother, more “listening” than “dancing”, often mid‑tempo)
#
# Group C – Acoustic/Art/Niche
#     Classical, Folk, Experimental
#     (more acoustic, often lower tempo or non‑beat‑driven)

# %%
c1 = ['Electronic', 'Hip-Hop', 'Pop', 'Rock', 'International']
c2 = ['Jazz', 'Blues', 'Instrumental', 'Easy Listening']
c3 = ['Classical', 'Folk', 'Experimental']

# %% [markdown]
# Prediction using the echonest dataset

# %%
# Choose numeric columns
# group by c1, c2, c3 groups

df_echonest_coarse = df_echonest_final.copy()
df_echonest_coarse['genre_top'] = df_echonest_final['genre_top'].apply(
    lambda g: 'c1' if g in c1 else ('c2' if g in c2 else 'c3')
)

print(df_echonest_coarse['genre_top'].value_counts())

# df = df_echonest_final.dropna(subset=num_cols + ['genre_top']).copy()

X = df_echonest_coarse[num_cols].values
y = df_echonest_coarse['genre_top'].values

# 2) Encode labels
le = LabelEncoder()
y_enc = le.fit_transform(y)   # integers 0..K-1

# 3) Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)
# Out:
# genre_top
# c1    8050
# c3    1568
# c2     787
# Name: count, dtype: int64

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    n_estimators=200,       # number of trees
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softprob',   # multi-class
    num_class=len(le.classes_),   # number of genres
    eval_metric='mlogloss',
    random_state=42,
    n_jobs=-1
)

xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1, num_class=3, ...)

# %%
y_pred = xgb.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

print(classification_report(
    y_test, y_pred,
    target_names=le.classes_
))
# Out:
# Accuracy: 0.857760691975012
#               precision    recall  f1-score   support
#
#           c1       0.88      0.97      0.92      1610
#           c2       0.68      0.16      0.26       157
#           c3       0.75      0.62      0.68       314
#
#     accuracy                           0.86      2081
#    macro avg       0.77      0.58      0.62      2081
# weighted avg       0.84      0.86      0.84      2081

# %%
# Visualize performance with a normalized confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm / cm.sum(axis=1, keepdims=True)
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Normalized Confusion Matrix (XGBoost)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Overall accuracy ≈ 0.85
# 85% of tracks’ coarse groups are predicted correctly.
#
# c1 (Electronic/Hip-Hop/Pop/Rock/International)
#
#     Precision 0.87: when model predicts c1, it’s usually right.
#
#     Recall 0.97: it finds almost all true c1 tracks.
#
#     F1 0.92: excellent.
#     → Model is very good at recognizing “mainstream/beat‑driven” tracks.
#
# c2 (Jazz/Blues/Instrumental/Easy Listening)
#
#     Precision 0.71: if it predicts c2, it’s often correct.
#
#     Recall 0.14: but it rarely predicts c2 at all.
#
#     F1 0.23: poor.
#     → Many true c2 tracks are misclassified as c1 or c3. This is the main weakness.
#
# c3 (Classical/Folk/Experimental)
#
#     Precision 0.75, recall 0.59, F1 0.66: reasonable but not as good as c1.

# %% [markdown]
# We re going to try to weight the c2 class because it is the most underpresented in the dataset

# %%
# if we use the by-default class weights from sklearn
# didn't perform well
# classes = np.unique(y_enc)          # encoded 0,1,2 for c1,c2,c3
# cw = compute_class_weight('balanced', classes=classes, y=y_enc)
# class_weights = dict(zip(classes, cw))

# # build sample weights vector for each training example
# w_train = np.array([class_weights[c] for c in y_train])
# print(class_weights)  

for w_c2 in [3.0, 5.0, 10.0]:
    class_weights = {0: 1.0, 1: w_c2, 2: 1.5}
    w_train = np.array([class_weights[c] for c in y_train])

    xgb.fit(X_train, y_train, sample_weight=w_train)
    y_pred = xgb.predict(X_test)

    print(f"\n=== c2 weight = {w_c2} ===")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# === c2 weight = 3.0 ===
# Accuracy: 0.8558385391638635
#               precision    recall  f1-score   support
#
#           c1       0.88      0.96      0.92      1610
#           c2       0.62      0.24      0.35       157
#           c3       0.72      0.62      0.67       314
#
#     accuracy                           0.86      2081
#    macro avg       0.74      0.61      0.65      2081
# weighted avg       0.84      0.86      0.84      2081
#
#
# === c2 weight = 5.0 ===
# Accuracy: 0.8529553099471407
#               precision    recall  f1-score   support
#
#           c1       0.89      0.96      0.92      1610
#           c2       0.51      0.28      0.36       157
#           c3       0.75      0.61      0.67       314
#
#     accuracy                           0.85      2081
#    macro avg       0.72      0.62      0.65      2081
# weighted avg       0.84      0.85      0.84      2081
#
#
# === c2 weight = 10.0 ===
# Accuracy: 0.8452666987025469
#               precision    recall  f1-score   support
#
#           c1       0.89      0.94      0.92      1610
#           c2       0.42      0.34      0.37       157
#           c3       0.74      0.59      0.66       314
#
#     accuracy                           0.85      2081
#    macro avg       0.68      0.62      0.65      2081
# weighted avg       0.83      0.85      0.84      2081

# %%
# Visualize performance with a normalized confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm / cm.sum(axis=1, keepdims=True)
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Normalized Confusion Matrix (XGBoost)')
plt.tight_layout()
plt.show()

# %% [markdown]
# We re going to try Random forests now and keeping the weighted classes

# %%
from sklearn.ensemble import RandomForestClassifier

xrf = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight=class_weights,   # help c2 again
    random_state=42,
    n_jobs=-1
)

xrf.fit(X_train, y_train)
y_pred = xrf.predict(X_test)

print("RF accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# RF accuracy: 0.8443056222969726
#               precision    recall  f1-score   support
#
#           c1       0.86      0.98      0.91      1610
#           c2       0.64      0.09      0.16       157
#           c3       0.77      0.54      0.63       314
#
#     accuracy                           0.84      2081
#    macro avg       0.75      0.54      0.57      2081
# weighted avg       0.83      0.84      0.81      2081

# %% [markdown]
# Even with class rebalancing, Random Forest strongly favors the majority class, while XGBoost handles the minority c2 group better, giving a higher macro‑F1. Therefore XGBoost is the preferred model for coarse‑genre prediction.

# %% [markdown]
# We are going to use Logistic Regression this time

# %%
from sklearn.linear_model import LogisticRegression

# X, y_enc, X_train, X_test, y_train, y_test as before 
log_reg = LogisticRegression(
    multi_class='multinomial',
    solver='lbfgs',
    class_weight=class_weights,   # auto‑upweights c2
    max_iter=1000,
    n_jobs=-1
)

log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)

print("LogReg accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# c:\Users\Chaima\Documents_local\3A\Supervised_Challenge\supervised_env\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogReg accuracy: 0.6448822681403171
#               precision    recall  f1-score   support
#
#           c1       0.93      0.73      0.82      1610
#           c2       0.14      0.66      0.23       157
#           c3       0.80      0.21      0.33       314
#
#     accuracy                           0.64      2081
#    macro avg       0.62      0.53      0.46      2081
# weighted avg       0.85      0.64      0.70      2081

# %% [markdown]
# LogReg is too aggressive on c2—many false positives, hurting overall performance and c3 badly. XGBoost is clearly the better compromise: higher macro‑F1 and much higher accuracy, with reasonably good c2.

# %% [markdown]
# # === We're going to do the same treatment to the spectral dataset to see if it gives better classification ===

# %% [markdown]
# Now we can begin clustering techniques  to help determine classes

# %% [markdown]
# Approach 1: autoencoder(spectral dataset)

# %%
encoder_features_spec = ['album_tracks', 'duration', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']
X_spec = df_spectral_num[encoder_features_spec].values
# Standarize
scaler_spec = StandardScaler()
X_scaled_spec = scaler_spec.fit_transform(X_spec)
input_dim_spec = X_scaled_spec.shape[1]

# %%
# Hyperparameters
encoding_dim = 10
hidden_dim = 24
epochs = 30
batch_size = 256

# encoder
input_layer_spec = layers.Input(shape=(input_dim_spec,))

h_spec = layers.Dense(hidden_dim, activation='relu')(input_layer_spec)

botteleneck_spec = layers.Dense(encoding_dim, activation='relu')(h_spec)

# decoder
h_dec_spec = layers.Dense(hidden_dim, activation='relu')(botteleneck_spec)
output_layer_spec = layers.Dense(input_dim_spec, activation='linear')(h_dec_spec)
# autoencoder models
autoencoder_spec = models.Model(inputs=input_layer_spec, outputs=output_layer_spec)
autoencoder_spec.compile(optimizer='adam', loss='mse')

# Train
history_spec = autoencoder_spec.fit(X_scaled_spec, X_scaled_spec,
                          epochs=epochs,
                          batch_size=batch_size,
                          shuffle=True,
                          validation_split=0.1,
                          verbose=1)
# Out:
# Epoch 1/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - loss: 0.4509 - val_loss: 0.1124
# Epoch 2/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0336 - val_loss: 0.0213
# Epoch 3/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0117 - val_loss: 0.0100
# Epoch 4/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 5/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 6/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 7/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0012 - val_loss: 9.8687e-04
# Epoch 8/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 6.7409e-04 - val_loss: 5.1152e-04
# Epoch 9/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.8612e-04 - val_loss: 2.5801e-04
# Epoch 10/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.9674e-04 - val_loss: 1.0122e-04
# Epoch 11/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.9995e-05 - val_loss: 6.7589e-05
# Epoch 12/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.5170e-05 - val_loss: 5.5524e-05
# Epoch 13/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 6.6392e-05 - val_loss: 2.7187e-05
# Epoch 14/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.0342e-05 - val_loss: 3.0789e-05
# Epoch 15/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 5.7790e-05 - val_loss: 5.7005e-05
# Epoch 16/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.5058e-05 - val_loss: 2.5075e-04
# Epoch 17/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 8.6351e-05 - val_loss: 6.6640e-05
# Epoch 18/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 6.2899e-04 - val_loss: 2.0991e-05
# Epoch 19/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.6293e-05 - val_loss: 8.2294e-06
# Epoch 20/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.7808e-05 - val_loss: 1.9566e-05
# Epoch 21/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 1.9384e-05 - val_loss: 5.5089e-06
# Epoch 22/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 2.4300e-05 - val_loss: 7.5812e-06
# Epoch 23/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 5.6528e-05 - val_loss: 1.4381e-05
# Epoch 24/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 8.0050e-05 - val_loss: 9.9617e-04
# Epoch 25/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.0031e-04 - val_loss: 5.2656e-06
# Epoch 26/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.5812e-06 - val_loss: 6.0764e-06
# Epoch 27/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 7.6873e-06 - val_loss: 1.3889e-05
# Epoch 28/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.7325e-05 - val_loss: 1.2461e-04
# Epoch 29/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.9796e-05 - val_loss: 4.3562e-06
# Epoch 30/30
# 343/343 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 2.4525e-04 - val_loss: 5.3204e-06

# %%
encoder_spec = models.Model(inputs=input_layer_spec, outputs=botteleneck_spec)

# Get the encoded representations
Z_spec = encoder_spec.predict(X_scaled_spec, batch_size=batch_size)
z_scaler_spec = StandardScaler()
Z_scaled_spec = z_scaler_spec.fit_transform(Z_spec)
# Out:
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
# We are going to run kmeans on latent space and assign cluster labels
k = 4
k_means_ae_spec = KMeans(n_clusters=k, random_state=42)
cluster_labels_ae_spec = k_means_ae_spec.fit_predict(Z_scaled_spec)

df_spectral_ae = df_spectral_final.copy()
df_spectral_ae['cluster_ae_spec'] = cluster_labels_ae_spec
# See which fine genres fall in which AE-cluster
ct_spec = pd.crosstab(df_spectral_ae['cluster_ae_spec'], df_spectral_ae['genre_top'])
ct_spec
# Out:
# genre_top        Blues  Classical  Easy Listening  Electronic  Experimental  \
# cluster_ae_spec
# 0                  766       1009            1193       10997         11798
# 1                    3         21              28          46           215
# 2                   39        125             109         825          2675
# 3                  577        693             768       10888          9030
#
# genre_top        Folk  Hip-Hop  Holiday  Instrumental  International  Jazz  \
# cluster_ae_spec
# 0                4913     2509        3          1187           1492  1140
# 1                  16        4        0             6              2     3
# 2                 256       12        0            88             78    64
# 3                2124     1854        1           713            896   689
#
# genre_top         Pop   Rock  Spoken
# cluster_ae_spec
# 0                4164  13977     294
# 1                 272     11       2
# 2                 121    219      88
# 3                2133   5933     219

# %%
# Convert counts to row-wise percentages
ct_spec_pct = ct_spec.div(ct_spec.sum(axis=1), axis=0) * 100

# Plot the percentage distribution
ct_spec_pct.plot(kind='bar', stacked=True, figsize=(8,5))
plt.xlabel('Autoencoder cluster')
plt.ylabel('Percentage of tracks (%)')
plt.title('genre_top percentage distribution inside AE clusters')
plt.tight_layout()
plt.show()

# %%
# Mean feature per cluster
mean_by_cluster = df_spectral_ae.groupby('cluster_ae_spec')[
    ['Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5',
    'Pop_PC1']
].mean()

mean_by_cluster.T.plot(kind='bar', figsize=(8,4))
plt.ylabel('Mean value')
plt.title('Mean musical features per AE cluster')
plt.tight_layout()
plt.show()

# %%
from collections import defaultdict
genre_to_cluster = (
    ct_spec_pct.idxmax(axis=0)   # choose cluster where genre % is maximum
    .to_dict()
)

cluster_to_genres = defaultdict(list)
for genre, cluster in genre_to_cluster.items():
    cluster_to_genres[cluster].append(genre)
for cluster in sorted(cluster_to_genres.keys()):
    print(f"Cluster {cluster}:")
    print(cluster_to_genres[cluster])
    print()
# Out:
# Cluster 0:
# ['Folk', 'Holiday', 'Instrumental', 'International', 'Jazz', 'Rock']
#
# Cluster 1:
# ['Classical', 'Easy Listening', 'Pop']
#
# Cluster 2:
# ['Experimental', 'Spoken']
#
# Cluster 3:
# ['Blues', 'Electronic', 'Hip-Hop']

# %% [markdown]
# As a spectral-based classification, it’s reasonable and defensible. It plausibly reflects “how the tracks sound”.
# The cluster 2 groups more “calm/melodic/instrumental” genres, which makes sense. But 0 is too broad and 1 is surprising.

# %% [markdown]
# Approach 2 : Clustering without autoencoding (spectral dataset)

# %%
df_spectral_final.head()
# Out:
#    album_tracks  duration genre_top  Spec_PC1  Spec_PC2  Spec_PC3  Spec_PC4  \
# 0            10       131   Hip-Hop  0.118641  1.163968 -0.037856  0.976482
# 1            10       185   Hip-Hop  0.196037 -0.143670 -0.278785  0.588802
# 2            10       183   Hip-Hop  1.123142  0.154781 -0.490849 -0.376471
# 3            10       213   Hip-Hop  0.707095 -0.136350 -0.154662  0.554418
# 4            10       162   Hip-Hop  0.450496 -1.025226  0.646793  1.410960
#
#    Spec_PC5   Pop_PC1
# 0  0.449219 -0.373249
# 1  0.068307 -0.369163
# 2 -0.140204 -0.372563
# 3 -0.467090 -0.241591
# 4 -0.149837 -0.371245

# %%
# We re going to try not encoding features and use all features in the dataset
df_spectral_kmeans = df_spectral_final.copy()
X_spec = df_spectral_kmeans.drop(columns=['genre_top']).values

kmeans_spec = KMeans(n_clusters=4, random_state=42)
cluster_labels_spec = kmeans_spec.fit_predict(X_spec)


df_spectral_kmeans['cluster_kmeans'] = cluster_labels_spec

# See which fine genres fall in which KMeans-cluster
ct_kmeans_spec = pd.crosstab(df_spectral_kmeans['cluster_kmeans'], df_spectral_kmeans['genre_top'])
# Convert counts to row-wise percentages
ct_kmeans_spec_pct = ct_kmeans_spec.div(ct_kmeans_spec.sum(axis=1), axis=0) * 100

# Plot the percentage distribution
ct_kmeans_spec_pct.plot(kind='bar', stacked=True, figsize=(8,5))
plt.xlabel('Autoencoder cluster')
plt.ylabel('Percentage of tracks (%)')
plt.title('genre_top percentage distribution inside AE clusters')
plt.tight_layout()
plt.show()

# %%
# Mean feature per cluster
mean_by_cluster = df_spectral_kmeans.groupby('cluster_kmeans')[
    ['Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5',
    'Pop_PC1']
].mean()

mean_by_cluster.T.plot(kind='bar', figsize=(8,4))
plt.ylabel('Mean value')
plt.title('Mean musical features per cluster')
plt.tight_layout()
plt.show()

# %%
from collections import defaultdict
genre_to_cluster = (
    ct_kmeans_spec_pct.idxmax(axis=0)   # choose cluster where genre % is maximum
    .to_dict()
)

cluster_to_genres = defaultdict(list)
for genre, cluster in genre_to_cluster.items():
    cluster_to_genres[cluster].append(genre)
for cluster in sorted(cluster_to_genres.keys()):
    print(f"Cluster {cluster}:")
    print(cluster_to_genres[cluster])
    print()
# Out:
# Cluster 0:
# ['Blues', 'Folk', 'Hip-Hop', 'Holiday', 'Instrumental', 'Pop', 'Rock']
#
# Cluster 1:
# ['Classical', 'Easy Listening', 'Experimental']
#
# Cluster 2:
# ['Electronic', 'Jazz']
#
# Cluster 3:
# ['International', 'Spoken']

# %% [markdown]
# Again mixing Electronic + Jazz is surprising genre-wise. Jazz’s harmonic, improvisational aspects contrast with electronic’s synthetic, beat-driven textures.
# Cluster 0 is a large mix of very different genres (Pop, Hip-Hop, Instrumental), reducing coherence.

# %% [markdown]
# Approach 3 : transform lines into genres instead of tracks (fot Spectral Features DataSet)

# %%
# we omit 'genre_top' since it's categorical
num_cols_spec = ['album_tracks', 'duration', 'Spec_PC1', 'Spec_PC2', 'Spec_PC3', 'Spec_PC4', 'Spec_PC5', 'Pop_PC1']

# Aggregate spectral features per genre using median
genre_df_spec = df_spectral_final.groupby('genre_top')[num_cols_spec].median().reset_index()

#Remove low-variance spectral features 
var_series_spec = genre_df_spec[num_cols_spec].var()
print(var_series_spec.sort_values())

selector = VarianceThreshold(threshold=0.01)
X_lowvar_spec = selector.fit_transform(genre_df_spec[num_cols_spec])

kept_cols_spec = genre_df_spec[num_cols_spec].columns[selector.get_support()]

print("Kept columns after low variance removal:")
for col in kept_cols_spec:
    print(col)
# Out:
# Spec_PC3           0.011358
# Pop_PC1            0.033094
# Spec_PC5           0.044213
# Spec_PC4           0.101341
# Spec_PC2           0.150308
# Spec_PC1           1.523238
# album_tracks       2.379121
# duration        3041.199176
# dtype: float64
# Kept columns after low variance removal:
# album_tracks
# duration
# Spec_PC1
# Spec_PC2
# Spec_PC3
# Spec_PC4
# Spec_PC5
# Pop_PC1

# %% [markdown]
# All the columns meet the variance threshold in this case.

# %%
# Scaling + KMeans clustering 
Xg_spec = genre_df_spec[kept_cols_spec].values

scaler_g_spec = StandardScaler()
Xg_scaled_spec = scaler_g_spec.fit_transform(Xg_spec)

kmeans_genre_spec = KMeans(n_clusters=4, random_state=42)
genre_cluster_labels_spec = kmeans_genre_spec.fit_predict(Xg_scaled_spec)

genre_df_spec['genre_cluster'] = genre_cluster_labels_spec

genre_df_spec.head()
# Out:
#         genre_top  album_tracks  duration  Spec_PC1  Spec_PC2  Spec_PC3  \
# 0           Blues          10.0     229.0  0.323857 -0.353338 -0.312840
# 1       Classical          14.0     190.5 -2.937884 -0.617172  0.011339
# 2  Easy Listening          11.0     224.0 -1.692197 -0.712778 -0.314865
# 3      Electronic          11.0     235.0  1.008415 -0.738047 -0.164181
# 4    Experimental          12.0     260.0 -0.388875 -0.378613 -0.202516
#
#    Spec_PC4  Spec_PC5   Pop_PC1  genre_cluster
# 0 -0.020434 -0.140962  0.057211              3
# 1  0.077011 -0.204056  0.178446              2
# 2  0.141153  0.069603  0.152453              3
# 3 -0.106035  0.230774 -0.202411              3
# 4  0.052829 -0.115598 -0.333410              0

# %%
# Print genres per cluster 
for c in sorted(genre_df_spec['genre_cluster'].unique()):
    print(f"\nCluster {c}:")
    print(genre_df_spec.loc[genre_df_spec['genre_cluster'] == c, 'genre_top'].tolist())
# Out:
# Cluster 0:
# ['Experimental', 'Folk', 'Hip-Hop', 'International', 'Pop', 'Rock', 'Spoken']
#
# Cluster 1:
# ['Holiday']
#
# Cluster 2:
# ['Classical']
#
# Cluster 3:
# ['Blues', 'Easy Listening', 'Electronic', 'Instrumental', 'Jazz']

# %% [markdown]
# Cluster 0 is a “catch-all” of very different genres (Pop, Rock, Hip-Hop, Experimental). This reduces intra-cluster similarity.
# This clustering is probably worst than the others.

# %% [markdown]
# After the 3 methods we choose the first approach's clustering and we're going to slightly change it :
# Cluster 0 – Popular & Folk:
# ['Pop', 'Rock', 'Hip-Hop', 'Folk']
# Rationale: These are mainstream, vocal-heavy, or culturally familiar genres.
#
# Cluster 1 – Electronic & Experimental:
# ['Electronic', 'Experimental', 'Jazz']
# Rationale: Jazz and Experimental pair with Electronic due to improvisation and sound exploration.
#
# Cluster 2 – Classical / Instrumental / Easy Listening:
# ['Classical', 'Easy Listening', 'Instrumental', 'Blues']
# Rationale: Calm, structured, mostly non-lyrical music—no change needed.
#
# Cluster 3 – Spoken / International / Blues:
# ['Spoken', 'Holiday', 'International', 'Pop'] Rationale: Narrative-driven, world-oriented, or soulful storytelling genres.

# %%
c1 = ['Pop', 'Rock', 'Hip-Hop', 'Folk']              # Mainstream vocal / popular
c2 = ['Electronic', 'Jazz', 'Experimental']          # Improvisation / electronic / experimental
c3 = ['Classical', 'Easy Listening', 'Instrumental', 'Blues']  # Calm / structured / soulful
c4 = ['Spoken', 'Holiday', 'International', 'Pop']   # Narrative / cultural / seasonal

# %% [markdown]
# Prediction using the spectral dataset

# %%
# Choose numeric columns
# group by c1, c2, c3, c4 groups

df_spectral_coarse = df_spectral_final.copy()
df_spectral_coarse['genre_top'] = df_spectral_final['genre_top'].apply(
    lambda g: 'c1' if g in c1 else ('c2' if g in c2 else ('c3' if g in c3 else 'c4'))
)

print(df_spectral_coarse['genre_top'].value_counts())

X_spec = df_spectral_coarse[num_cols_spec].values
y_spec = df_spectral_coarse['genre_top'].values

# 2) Encode labels
le_spec = LabelEncoder()
y_enc_spec = le_spec.fit_transform(y_spec)   # integers 0..K-1
# 3) Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_spec, y_enc_spec, test_size=0.2, random_state=42, stratify=y_enc_spec
)
# Out:
# genre_top
# c2    48370
# c1    38518
# c3     7325
# c4     3075
# Name: count, dtype: int64

# %%
from xgboost import XGBClassifier

xgb_spec = XGBClassifier(
    n_estimators=200,       # number of trees
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softprob',   # multi-class
    num_class=len(le.classes_),   # number of genres
    eval_metric='mlogloss',
    random_state=42,
    n_jobs=-1
)

xgb_spec.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1, num_class=3, ...)

# %%
y_pred = xgb_spec.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

print(classification_report(
    y_test, y_pred,
    target_names=le_spec.classes_
))
# Out:
# Accuracy: 0.6594716825984172
#               precision    recall  f1-score   support
#
#           c1       0.64      0.66      0.65      7704
#           c2       0.68      0.76      0.71      9674
#           c3       0.62      0.26      0.37      1465
#           c4       0.68      0.03      0.07       615
#
#     accuracy                           0.66     19458
#    macro avg       0.65      0.43      0.45     19458
# weighted avg       0.66      0.66      0.64     19458

# %%
# Visualize performance with a normalized confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm / cm.sum(axis=1, keepdims=True)
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=le_spec.classes_, yticklabels=le_spec.classes_)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Normalized Confusion Matrix (XGBoost)')
plt.tight_layout()
plt.show()

# %% [markdown]
# We re going to try to weight the c4 class because it is the most underpresented in the dataset

# %%
for w_c4 in [12.0, 15.0, 18.0]:
    class_weights = {0: 1.5, 1: 2.0, 2: 6.0 , 3: w_c4}
    w_train = np.array([class_weights[c] for c in y_train])

    xgb_spec.fit(X_train, y_train, sample_weight=w_train)
    y_pred = xgb_spec.predict(X_test)

    print(f"\n=== c4 weight = {w_c4} ===")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=le_spec.classes_))
# Out:
# === c4 weight = 12.0 ===
# Accuracy: 0.6274026107513619
#               precision    recall  f1-score   support
#
#           c1       0.70      0.51      0.59      7704
#           c2       0.66      0.76      0.71      9674
#           c3       0.38      0.53      0.44      1465
#           c4       0.22      0.25      0.24       615
#
#     accuracy                           0.63     19458
#    macro avg       0.49      0.51      0.49     19458
# weighted avg       0.64      0.63      0.63     19458
#
#
# === c4 weight = 15.0 ===
# Accuracy: 0.6186144516394285
#               precision    recall  f1-score   support
#
#           c1       0.70      0.49      0.58      7704
#           c2       0.67      0.75      0.71      9674
#           c3       0.38      0.52      0.44      1465
#           c4       0.17      0.32      0.23       615
#
#     accuracy                           0.62     19458
#    macro avg       0.48      0.52      0.49     19458
# weighted avg       0.64      0.62      0.62     19458
#
#
# === c4 weight = 18.0 ===
# Accuracy: 0.6094665433240827
#               precision    recall  f1-score   support
#
#           c1       0.71      0.48      0.57      7704
#           c2       0.67      0.75      0.71      9674
#           c3       0.38      0.51      0.44      1465
#           c4       0.15      0.38      0.21       615
#
#     accuracy                           0.61     19458
#    macro avg       0.48      0.53      0.48     19458
# weighted avg       0.65      0.61      0.62     19458

# %%
# Visualize performance with a normalized confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_norm = cm / cm.sum(axis=1, keepdims=True)
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=le_spec.classes_, yticklabels=le_spec.classes_)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Normalized Confusion Matrix (XGBoost)')
plt.tight_layout()
plt.show()

# %% [markdown]
# We re going to try Random forests now and keeping the weighted classes

# %%
from sklearn.ensemble import RandomForestClassifier

xrf_spec = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight=class_weights,   # help c2 again
    random_state=42,
    n_jobs=-1
)

xrf_spec.fit(X_train, y_train)
y_pred = xrf_spec.predict(X_test)

print("RF accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le_spec.classes_))
# Out:
# RF accuracy: 0.6502723815397266
#               precision    recall  f1-score   support
#
#           c1       0.65      0.60      0.63      7704
#           c2       0.66      0.78      0.71      9674
#           c3       0.53      0.31      0.39      1465
#           c4       0.63      0.06      0.12       615
#
#     accuracy                           0.65     19458
#    macro avg       0.62      0.44      0.46     19458
# weighted avg       0.65      0.65      0.64     19458

# %% [markdown]
# Even with class rebalancing, Random Forest strongly favors the majority class, while XGBoost handles the minority c4 group better, giving a higher macro‑F1. Therefore XGBoost is the preferred model for coarse‑genre prediction.

# %% [markdown]
# We are going to use Logistic Regression this time

# %%
from sklearn.linear_model import LogisticRegression

# X, y_enc, X_train, X_test, y_train, y_test as before 
log_reg_spec = LogisticRegression(
    multi_class='multinomial',
    solver='lbfgs',
    class_weight=class_weights,   # auto‑upweights c2
    max_iter=1000,
    n_jobs=-1
)

log_reg_spec.fit(X_train, y_train)
y_pred = log_reg_spec.predict(X_test)

print("LogReg accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=le_spec.classes_))
# Out:
# c:\Users\Chaima\Documents_local\3A\Supervised_Challenge\supervised_env\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogReg accuracy: 0.5053448453078425
#               precision    recall  f1-score   support
#
#           c1       0.62      0.25      0.36      7704
#           c2       0.55      0.76      0.64      9674
#           c3       0.30      0.30      0.30      1465
#           c4       0.07      0.16      0.10       615
#
#     accuracy                           0.51     19458
#    macro avg       0.38      0.37      0.35     19458
# weighted avg       0.54      0.51      0.48     19458

# %% [markdown]
# LogReg is too aggressive on c4—many false positives, hurting overall performance and c1 badly. XGBoost is clearly the better compromise: higher macro‑F1 and much higher accuracy, with reasonably good c4.

# %% [markdown]
# Conclusion:
# After doing the same treatment on the spectral dataset we realize that the echonest one is far better because it relies on many musical insights whereas the spectral one only give pure audio insights which isn't  enough to predict genres.
