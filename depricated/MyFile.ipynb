# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter
import ast

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (25, 20)

# %%
#Loading datasets
genres = pd.read_csv('data/genres.csv')
tracks = pd.read_csv('data/tracks.tsv', sep='\t')
echonest = pd.read_csv('data/echonest_features.tsv', sep='\t')
spectral = pd.read_csv('data/spectral_features.tsv', sep='\t')

# %%
df = tracks.merge(spectral, on='track_id')

# %%
df.to_csv('data/merged_data.csv', index=False)

# %%
df
# Out:
#        track_id                    album_title  album_tracks  artist_latitude  \
# 0         11870           Wildahead Portibeast            10              NaN
# 1         11871           Wildahead Portibeast            10              NaN
# 2         11872           Wildahead Portibeast            10              NaN
# 3         11873           Wildahead Portibeast            10              NaN
# 4         11874           Wildahead Portibeast            10              NaN
# ...         ...                            ...           ...              ...
# 99990    155316  Live at Monty Hall, 2/17/2017             6              NaN
# 99991    155317  Live at Monty Hall, 2/17/2017             6              NaN
# 99992    155318  Live at Monty Hall, 2/17/2017             6              NaN
# 99993    155319  Live at Monty Hall, 2/17/2017             6              NaN
# 99994    155320      What I Tell Myself Vol. 2            11              NaN
#
#        artist_longitude           artist_name  duration  favorites genre_top  \
# 0                   NaN  Wildahead Portibeast       131          0   Hip-Hop
# 1                   NaN  Wildahead Portibeast       185          0   Hip-Hop
# 2                   NaN  Wildahead Portibeast       183          0   Hip-Hop
# 3                   NaN  Wildahead Portibeast       213          3   Hip-Hop
# 4                   NaN  Wildahead Portibeast       162          0   Hip-Hop
# ...                 ...                   ...       ...        ...       ...
# 99990               NaN               Spowder       162          1      Rock
# 99991               NaN               Spowder       217          1      Rock
# 99992               NaN               Spowder       404          2      Rock
# 99993               NaN               Spowder       146          0      Rock
# 99994               NaN      Forget the Whale       198          1       NaN
#
#               genres  ... spectral_centroid_min_01  spectral_centroid_skew_01  \
# 0               [21]  ...               327.569489                   2.080017
# 1               [21]  ...               187.277390                   1.886271
# 2               [21]  ...                99.604340                   1.492531
# 3               [21]  ...               203.401001                   0.916191
# 4               [21]  ...               244.832825                   2.521557
# ...              ...  ...                      ...                        ...
# 99990           [25]  ...               149.618149                   0.828882
# 99991           [25]  ...               139.838211                   0.872176
# 99992           [25]  ...               193.173676                   0.563925
# 99993           [25]  ...               282.028870                   1.111761
# 99994  [10, 12, 169]  ...               200.906952                   3.576910
#
#        spectral_centroid_std_01 spectral_rolloff_kurtosis_01  \
# 0                    575.112488                     2.839292
# 1                    655.114319                     2.036670
# 2                    645.915894                    -0.463741
# 3                    615.655090                    -0.114326
# 4                    755.226440                     4.567743
# ...                         ...                          ...
# 99990                264.716766                     4.309953
# 99991                412.968170                     1.246215
# 99992                368.312073                     1.746728
# 99993                296.829010                     4.741753
# 99994               1355.187256                     3.555222
#
#        spectral_rolloff_max_01  spectral_rolloff_mean_01  \
# 0                  8968.579102               2338.119629
# 1                  9560.742188               2132.796143
# 2                  9345.410156               2760.100342
# 3                  9722.241211               2445.449219
# 4                 10142.138672               2265.638672
# ...                        ...                       ...
# 99990              9420.776367               1732.244019
# 99991              6858.325195               1860.772095
# 99992              9517.675781               2176.805664
# 99993              9280.810547               2363.244385
# 99994             10540.502930               3432.988770
#
#        spectral_rolloff_median_01  spectral_rolloff_min_01  \
# 0                     1981.054688               516.796875
# 1                     1830.322266               226.098633
# 2                     2583.984375                64.599609
# 3                     2271.752930                86.132812
# 4                     1905.688477               215.332031
# ...                           ...                      ...
# 99990                 1614.990234                75.366211
# 99991                 1614.990234                86.132812
# 99992                 2056.420898               172.265625
# 99993                 2260.986328               258.398438
# 99994                 3133.081055               129.199219
#
#        spectral_rolloff_skew_01  spectral_rolloff_std_01
# 0                      1.812383              1234.268433
# 1                      1.412759              1387.095459
# 2                      0.245426              1420.888672
# 3                      0.581035              1330.056030
# 4                      1.849876              1474.148682
# ...                         ...                      ...
# 99990                  0.902133               672.831116
# 99991                  0.974457              1039.222412
# 99992                  1.054271               932.816101
# 99993                  1.253278               758.186890
# 99994                  1.657281              2036.196777
#
# [99995 rows x 35 columns]

# %%
df.shape
# Out:
# (99995, 35)

# %%
df.columns
# Out:
# Index(['track_id', 'album_title', 'album_tracks', 'artist_latitude',
#        'artist_longitude', 'artist_name', 'duration', 'favorites', 'genre_top',
#        'genres', 'genres_all', 'interest', 'listens', 'title',
#        'spectral_bandwidth_kurtosis_01', 'spectral_bandwidth_max_01',
#        'spectral_bandwidth_mean_01', 'spectral_bandwidth_median_01',
#        'spectral_bandwidth_min_01', 'spectral_bandwidth_skew_01',
#        'spectral_bandwidth_std_01', 'spectral_centroid_kurtosis_01',
#        'spectral_centroid_max_01', 'spectral_centroid_mean_01',
#        'spectral_centroid_median_01', 'spectral_centroid_min_01',
#        'spectral_centroid_skew_01', 'spectral_centroid_std_01',
#        'spectral_rolloff_kurtosis_01', 'spectral_rolloff_max_01',
#        'spectral_rolloff_mean_01', 'spectral_rolloff_median_01',
#        'spectral_rolloff_min_01', 'spectral_rolloff_skew_01',
#        'spectral_rolloff_std_01'],
#       dtype='object')

# %%
# Nombre de valeurs manquantes par colonne
missing_count = df.isnull().sum()

# Pourcentage de valeurs manquantes
missing_percent = (df.isnull().sum() / len(df)) * 100

# Tableau récapitulatif
missing_df = pd.DataFrame({
    "Missing Count": missing_count,
    "Missing %": missing_percent
})

missing_df
# Out:
#                                 Missing Count  Missing %
# track_id                                    0   0.000000
# album_title                               911   0.911046
# album_tracks                                0   0.000000
# artist_latitude                         59788  59.790990
# artist_longitude                        59788  59.790990
# artist_name                                 0   0.000000
# duration                                    0   0.000000
# favorites                                   0   0.000000
# genre_top                               55362  55.364768
# genres                                      0   0.000000
# genres_all                                  0   0.000000
# interest                                    0   0.000000
# listens                                     0   0.000000
# title                                       1   0.001000
# spectral_bandwidth_kurtosis_01              0   0.000000
# spectral_bandwidth_max_01                   0   0.000000
# spectral_bandwidth_mean_01                  0   0.000000
# spectral_bandwidth_median_01                0   0.000000
# spectral_bandwidth_min_01                   0   0.000000
# spectral_bandwidth_skew_01                  0   0.000000
# spectral_bandwidth_std_01                   0   0.000000
# spectral_centroid_kurtosis_01               0   0.000000
# spectral_centroid_max_01                    0   0.000000
# spectral_centroid_mean_01                   0   0.000000
# spectral_centroid_median_01                 0   0.000000
# spectral_centroid_min_01                    0   0.000000
# spectral_centroid_skew_01                   0   0.000000
# spectral_centroid_std_01                    0   0.000000
# spectral_rolloff_kurtosis_01                0   0.000000
# spectral_rolloff_max_01                     0   0.000000
# spectral_rolloff_mean_01                    0   0.000000
# spectral_rolloff_median_01                  0   0.000000
# spectral_rolloff_min_01                     0   0.000000
# spectral_rolloff_skew_01                    0   0.000000
# spectral_rolloff_std_01                     0   0.000000

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100
plt.figure(figsize=(12, 6))
missing_percent.sort_values(ascending=False).plot(kind='bar')

plt.title("Pourcentage de valeurs manquantes par colonne")
plt.ylabel("Pourcentage (%)")
plt.xlabel("Colonnes")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
"""
Script pour afficher l'arbre complet de la hiérarchie des genres
"""

import pandas as pd
from collections import defaultdict

# ============================================================================
# FONCTION POUR CONSTRUIRE L'ARBRE
# ============================================================================

def build_genre_tree(df_genres):
    """
    Construit la structure d'arbre des genres
    
    Returns:
    --------
    dict : {parent_id: [list of children]}
    """
    tree = defaultdict(list)
    
    for _, row in df_genres.iterrows():
        parent_id = row['genre_parent_id']
        genre_id = row['genre_id']
        genre_title = row['genre_title']
        
        if pd.isna(parent_id):
            # Genre ROOT
            tree[None].append({
                'id': genre_id,
                'title': genre_title,
                'is_root': True
            })
        else:
            # Sous-genre
            tree[int(parent_id)].append({
                'id': genre_id,
                'title': genre_title,
                'is_root': False
            })
    
    return tree

# ============================================================================
# FONCTION POUR AFFICHER L'ARBRE (VERSION TEXTE)
# ============================================================================

def print_genre_tree(df_genres, max_depth=3):
    """
    Affiche l'arbre des genres en format texte
    
    Parameters:
    -----------
    df_genres : DataFrame
        DataFrame des genres
    max_depth : int
        Profondeur maximale à afficher
    """
    tree = build_genre_tree(df_genres)
    
    print("=" * 80)
    print("ARBRE COMPLET DES GENRES")
    print("=" * 80)
    print()
    
    def print_node(genre_id, genre_title, level=0, prefix="", is_last=True):
        """Affiche un nœud et ses enfants récursivement"""
        
        # Limite de profondeur
        if level >= max_depth:
            return
        
        # Symboles pour l'arbre
        if level == 0:
            connector = ""
            branch = "┌─ "
        else:
            connector = "│  " if not is_last else "   "
            branch = "└─ " if is_last else "├─ "
        
        # Affiche le genre actuel
        indent = prefix + branch if level > 0 else ""
        print(f"{indent}{genre_title} (ID: {genre_id})")
        
        # Récupère les enfants
        children = tree.get(genre_id, [])
        
        if children and level < max_depth - 1:
            # Nouveau préfixe pour les enfants
            new_prefix = prefix + ("   " if is_last else "│  ")
            
            # Affiche chaque enfant
            for i, child in enumerate(children):
                is_last_child = (i == len(children) - 1)
                print_node(
                    child['id'], 
                    child['title'], 
                    level + 1, 
                    new_prefix, 
                    is_last_child
                )
    
    # Affiche tous les genres ROOT et leurs descendants
    root_genres = tree[None]
    root_genres.sort(key=lambda x: x['id'])
    
    for i, root in enumerate(root_genres):
        print_node(root['id'], root['title'], level=0)
        if i < len(root_genres) - 1:
            print()  # Ligne vide entre les arbres ROOT
    
    print()
    print("=" * 80)

# ============================================================================
# FONCTION POUR CRÉER UN ARBRE VISUEL (GRAPHIQUE)
# ============================================================================

def create_visual_genre_tree(df_genres, output_path='genre_tree.png'):
    """
    Crée une visualisation graphique de l'arbre des genres
    """
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    from matplotlib.patches import FancyBboxPatch
    import numpy as np
    
    tree = build_genre_tree(df_genres)
    
    # Crée une figure large
    fig, ax = plt.subplots(figsize=(20, 14))
    ax.set_xlim(0, 100)
    ax.set_ylim(0, 100)
    ax.axis('off')
    
    # Titre
    ax.text(50, 97, 'ARBRE HIÉRARCHIQUE DES GENRES', 
            ha='center', fontsize=20, fontweight='bold',
            bbox=dict(boxstyle='round,pad=0.8', facecolor='lightblue', 
                     edgecolor='black', linewidth=2))
    
    # Positions
    root_genres = sorted(tree[None], key=lambda x: x['id'])
    num_roots = len(root_genres)
    
    y_start = 85
    y_spacing = 6
    
    colors = {
        'root': '#2ecc71',
        'child': '#3498db',
        'grandchild': '#e74c3c'
    }
    
    current_y = y_start
    
    for root in root_genres[:8]:  # Affiche les 8 premiers pour la clarté
        # Dessine le genre ROOT
        root_box = FancyBboxPatch(
            (5, current_y - 1), 15, 2.5,
            boxstyle="round,pad=0.3",
            edgecolor='black', facecolor=colors['root'], 
            linewidth=2, alpha=0.7
        )
        ax.add_patch(root_box)
        
        ax.text(12.5, current_y + 0.25, f"{root['title']}\n(ID: {root['id']})",
                ha='center', va='center', fontsize=9, fontweight='bold')
        
        # Dessine les enfants
        children = tree.get(root['id'], [])
        
        if children:
            num_children = min(len(children), 10)  # Max 10 enfants affichés
            child_spacing = 2.8
            child_start_y = current_y + (num_children - 1) * child_spacing / 2
            
            for i, child in enumerate(children[:num_children]):
                child_y = child_start_y - i * child_spacing
                
                # Ligne de connexion
                ax.plot([20, 30], [current_y + 0.25, child_y], 
                       'k-', linewidth=1, alpha=0.5)
                
                # Boîte enfant
                child_box = FancyBboxPatch(
                    (30, child_y - 0.8), 12, 1.8,
                    boxstyle="round,pad=0.2",
                    edgecolor='black', facecolor=colors['child'],
                    linewidth=1.5, alpha=0.7
                )
                ax.add_patch(child_box)
                
                ax.text(36, child_y, f"{child['title'][:20]}\n({child['id']})",
                        ha='center', va='center', fontsize=7)
                
                # Petits-enfants (si existants)
                grandchildren = tree.get(child['id'], [])
                if grandchildren and i < 3:  # Seulement pour les 3 premiers
                    gc_y = child_y
                    ax.plot([42, 48], [child_y, gc_y], 
                           'k-', linewidth=0.8, alpha=0.4)
                    
                    gc_box = FancyBboxPatch(
                        (48, gc_y - 0.6), 10, 1.2,
                        boxstyle="round,pad=0.15",
                        edgecolor='black', facecolor=colors['grandchild'],
                        linewidth=1, alpha=0.6
                    )
                    ax.add_patch(gc_box)
                    
                    gc_text = f"({len(grandchildren)} sub)"
                    ax.text(53, gc_y, gc_text,
                           ha='center', va='center', fontsize=6, style='italic')
        
        current_y -= y_spacing
    
    # Légende
    legend_elements = [
        mpatches.Patch(facecolor=colors['root'], edgecolor='black', 
                      label='Genre ROOT (niveau 0)'),
        mpatches.Patch(facecolor=colors['child'], edgecolor='black', 
                      label='Sous-genre (niveau 1)'),
        mpatches.Patch(facecolor=colors['grandchild'], edgecolor='black', 
                      label='Sous-sous-genre (niveau 2)')
    ]
    ax.legend(handles=legend_elements, loc='lower right', fontsize=10)
    
    # Note
    note_text = f"Note : Affiche {min(8, num_roots)}/{num_roots} genres ROOT\npour la clarté du graphique"
    ax.text(50, 5, note_text, ha='center', fontsize=9, style='italic',
           bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.5))
    
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
    print(f"✓ Arbre visuel sauvegardé : {output_path}")
    plt.close()

# ============================================================================
# FONCTION POUR AFFICHER UN GENRE SPÉCIFIQUE
# ============================================================================

def display_genre_family(df_genres, genre_id, max_depth=3):
    """
    Affiche l'arbre d'un genre spécifique et sa famille
    """
    tree = build_genre_tree(df_genres)
    genre_map = dict(zip(df_genres['genre_id'], df_genres['genre_title']))
    
    genre_title = genre_map.get(genre_id, "Unknown")
    
    print("=" * 80)
    print(f"FAMILLE DU GENRE : {genre_title} (ID: {genre_id})")
    print("=" * 80)
    print()
    
    def print_children(parent_id, level=0):
        children = tree.get(parent_id, [])
        
        if level >= max_depth or not children:
            return
        
        for i, child in enumerate(children):
            is_last = (i == len(children) - 1)
            
            # Symboles
            if is_last:
                branch = "└─ "
                continuation = "   "
            else:
                branch = "├─ "
                continuation = "│  "
            
            indent = "   " * level
            print(f"{indent}{branch}{child['title']} (ID: {child['id']})")
            
            # Récursion pour les petits-enfants
            grandchildren = tree.get(child['id'], [])
            if grandchildren:
                for j, gc in enumerate(grandchildren):
                    is_last_gc = (j == len(grandchildren) - 1)
                    gc_branch = "└─ " if is_last_gc else "├─ "
                    gc_indent = indent + continuation
                    print(f"{gc_indent}{gc_branch}{gc['title']} (ID: {gc['id']})")
    
    print(f"┌─ {genre_title} (ID: {genre_id}) [ROOT]")
    print_children(genre_id)
    print()
    print("=" * 80)

# ============================================================================
# FONCTION POUR STATISTIQUES DE L'ARBRE
# ============================================================================

def print_tree_statistics(df_genres):
    """Affiche les statistiques de l'arbre"""
    tree = build_genre_tree(df_genres)
    
    print("\n" + "=" * 80)
    print("STATISTIQUES DE L'ARBRE")
    print("=" * 80)
    
    # Compte les niveaux
    root_count = len(tree[None])
    
    level1_count = 0
    level2_count = 0
    
    for root in tree[None]:
        children = tree.get(root['id'], [])
        level1_count += len(children)
        
        for child in children:
            grandchildren = tree.get(child['id'], [])
            level2_count += len(grandchildren)
    
    print(f"\n📊 Répartition par niveau :")
    print(f"  • Niveau 0 (ROOT)      : {root_count:3d} genres")
    print(f"  • Niveau 1 (enfants)   : {level1_count:3d} genres")
    print(f"  • Niveau 2 (p-enfants) : {level2_count:3d} genres")
    print(f"  • TOTAL                : {len(df_genres):3d} genres")
    
    # Genres avec le plus d'enfants
    print(f"\n🏆 Top 5 genres avec le plus d'enfants :")
    
    genre_children_count = []
    for root in tree[None]:
        children = tree.get(root['id'], [])
        genre_children_count.append({
            'id': root['id'],
            'title': root['title'],
            'children': len(children)
        })
    
    genre_children_count.sort(key=lambda x: x['children'], reverse=True)
    
    for i, genre in enumerate(genre_children_count[:5], 1):
        print(f"  {i}. {genre['title']:20s} : {genre['children']:2d} sous-genres")
    
    print("\n" + "=" * 80)

# ============================================================================
# FONCTION PRINCIPALE
# ============================================================================

def display_complete_genre_tree(data_source, 
                                 show_text=True, 
                                 create_visual=True,
                                 show_stats=True,
                                 output_dir='./'):
    """
    Affiche l'arbre complet des genres
    
    Parameters:
    -----------
    data_source : DataFrame ou str
        DataFrame des genres ou chemin vers le CSV
    show_text : bool
        Afficher l'arbre en mode texte
    create_visual : bool
        Créer une visualisation graphique
    show_stats : bool
        Afficher les statistiques
    output_dir : str
        Dossier pour sauvegarder les visualisations
    """
    # Charge les données
    if isinstance(data_source, pd.DataFrame):
        df_genres = data_source
        print(f"✓ DataFrame chargé : {len(df_genres)} genres")
    else:
        df_genres = pd.read_csv(data_source)
        print(f"✓ Fichier chargé : {len(df_genres)} genres")
    
    # Affiche l'arbre texte
    if show_text:
        print_genre_tree(df_genres, max_depth=3)
    
    # Affiche les statistiques
    if show_stats:
        print_tree_statistics(df_genres)
    
    # Crée la visualisation
    if create_visual:
        print("\n📊 Création de la visualisation graphique...")
        output_path = f"{output_dir}/genre_tree_complete.png"
        create_visual_genre_tree(df_genres, output_path)
    
    print("\n✅ Arbre des genres affiché avec succès !")
    
    return df_genres

# ============================================================================
# UTILISATION
# ============================================================================

if __name__ == "__main__":
    # OPTION 1 : Si tu as un DataFrame 'genres'
    # display_complete_genre_tree(genres, output_dir='./output')
    
    # OPTION 2 : Si tu as le chemin du fichier
    display_complete_genre_tree(genres)
    
    # Pour afficher une famille spécifique :
    # df_genres = pd.read_csv('genres.csv')
    # display_genre_family(df_genres, 12)  # Rock
    #display_genre_family(genres, 38)  # Electronic
# Out:
# ✓ DataFrame chargé : 164 genres
# ================================================================================
# ARBRE COMPLET DES GENRES
# ================================================================================
#
# International (ID: 2)
#    ├─ Latin America (ID: 46)
#    │  ├─ Cumbia (ID: 502)
#    │  ├─ Salsa (ID: 808)
#    │  └─ Tango (ID: 1060)
#    ├─ French (ID: 77)
#    ├─ Reggae - Dub (ID: 79)
#    │  └─ Reggae - Dancehall (ID: 602)
#    ├─ Indian (ID: 86)
#    │  ├─ N. Indian Traditional (ID: 173)
#    │  ├─ South Indian Traditional (ID: 174)
#    │  └─ Bollywood (ID: 175)
#    ├─ African (ID: 92)
#    │  ├─ Afrobeat (ID: 81)
#    │  └─ North African (ID: 214)
#    ├─ Middle East (ID: 102)
#    │  └─ Turkish (ID: 1032)
#    ├─ Polka (ID: 117)
#    ├─ Balkan (ID: 118)
#    ├─ Europe (ID: 130)
#    │  ├─ Romany (Gypsy) (ID: 524)
#    │  ├─ Spanish (ID: 619)
#    │  ├─ Klezmer (ID: 741)
#    │  └─ Fado (ID: 1156)
#    ├─ Brazilian (ID: 171)
#    ├─ Asia-Far East (ID: 172)
#    ├─ Pacific (ID: 176)
#    ├─ Celtic (ID: 177)
#    ├─ Flamenco (ID: 232)
#    └─ Latin (ID: 504)
#
# Blues (ID: 3)
#    ├─ Soul-RnB (ID: 14)
#    │  ├─ Disco (ID: 11)
#    │  └─ Funk (ID: 19)
#    └─ Gospel (ID: 567)
#
# Jazz (ID: 4)
#    ├─ Jazz: Vocal (ID: 37)
#    ├─ Free-Jazz (ID: 74)
#    ├─ Jazz: Out (ID: 97)
#    ├─ Be-Bop (ID: 178)
#    ├─ Big Band/Swing (ID: 179)
#    ├─ Nu-Jazz (ID: 810)
#    └─ Modern Jazz (ID: 906)
#
# Classical (ID: 5)
#    ├─ 20th Century Classical (ID: 187)
#    ├─ Composed Music (ID: 322)
#    ├─ Opera (ID: 441)
#    ├─ Chamber Music (ID: 442)
#    ├─ Choral Music (ID: 443)
#    ├─ Symphony (ID: 444)
#    └─ Contemporary Classical (ID: 659)
#
# Pop (ID: 10)
#    ├─ Experimental Pop (ID: 76)
#    └─ Synth Pop (ID: 362)
#
# Rock (ID: 12)
#    ├─ Punk (ID: 25)
#    │  ├─ Electro-Punk (ID: 64)
#    │  ├─ No Wave (ID: 71)
#    │  ├─ Post-Punk (ID: 89)
#    │  ├─ Hardcore (ID: 109)
#    │  └─ Power-Pop (ID: 111)
#    ├─ Post-Rock (ID: 26)
#    │  └─ Space-Rock (ID: 113)
#    ├─ Lo-Fi (ID: 27)
#    ├─ Metal (ID: 31)
#    │  ├─ Death-Metal (ID: 101)
#    │  ├─ Black-Metal (ID: 167)
#    │  └─ Grindcore (ID: 439)
#    ├─ Krautrock (ID: 36)
#    ├─ Loud-Rock (ID: 45)
#    │  └─ Noise-Rock (ID: 53)
#    ├─ Psych-Rock (ID: 58)
#    ├─ Indie-Rock (ID: 66)
#    ├─ Industrial (ID: 70)
#    ├─ Garage (ID: 85)
#    │  └─ Surf (ID: 404)
#    ├─ New Wave (ID: 88)
#    ├─ Progressive (ID: 98)
#    ├─ Goth (ID: 314)
#    ├─ Shoegaze (ID: 359)
#    └─ Rock Opera (ID: 440)
#
# Easy Listening (ID: 13)
#    ├─ Soundtrack (ID: 18)
#    │  └─ Compilation (ID: 538)
#    ├─ Ambient (ID: 107)
#    ├─ Easy Listening: Vocal (ID: 170)
#    ├─ New Age (ID: 267)
#    └─ Lounge (ID: 311)
#
# Electronic (ID: 15)
#    ├─ Ambient Electronic (ID: 42)
#    ├─ Techno (ID: 181)
#    │  └─ Bigbeat (ID: 401)
#    ├─ House (ID: 182)
#    │  └─ Chill-out (ID: 400)
#    ├─ Glitch (ID: 183)
#    ├─ Minimal Electronic (ID: 184)
#    ├─ Breakcore - Hard (ID: 185)
#    ├─ IDM (ID: 236)
#    ├─ Trip-Hop (ID: 286)
#    ├─ Dance (ID: 296)
#    ├─ Chip Music (ID: 297)
#    │  └─ Chiptune (ID: 240)
#    ├─ Drum & Bass (ID: 337)
#    ├─ Dubstep (ID: 468)
#    │  └─ Skweee (ID: 491)
#    ├─ Downtempo (ID: 495)
#    └─ Jungle (ID: 695)
#
# Folk (ID: 17)
#    ├─ Old-Time / Historic (ID: 8)
#    ├─ Country (ID: 9)
#    │  ├─ Bluegrass (ID: 63)
#    │  ├─ Americana (ID: 137)
#    │  ├─ Rockabilly (ID: 169)
#    │  └─ Country & Western (ID: 651)
#    ├─ Psych-Folk (ID: 33)
#    ├─ Free-Folk (ID: 49)
#    ├─ Freak-Folk (ID: 94)
#    ├─ Singer-Songwriter (ID: 103)
#    └─ British Folk (ID: 180)
#
# Spoken (ID: 20)
#    ├─ Comedy (ID: 7)
#    ├─ Radio (ID: 65)
#    │  ├─ Radio Art (ID: 43)
#    │  ├─ Interview (ID: 166)
#    │  └─ Talk Radio (ID: 189)
#    ├─ Spoken Weird (ID: 138)
#    ├─ Poetry (ID: 188)
#    ├─ Banter (ID: 374)
#    ├─ Spoken Word (ID: 378)
#    ├─ Radio Theater (ID: 428)
#    └─ Musical Theater (ID: 465)
#
# Hip-Hop (ID: 21)
#    ├─ Nerdcore (ID: 83)
#    ├─ Alternative Hip-Hop (ID: 100)
#    ├─ Rap (ID: 539)
#    ├─ Breakbeat (ID: 542)
#    ├─ Abstract Hip-Hop (ID: 580)
#    ├─ Wonky (ID: 693)
#    ├─ hiphop (ID: 806)
#    └─ Hip-Hop Beats (ID: 811)
#
# Experimental (ID: 38)
#    ├─ Avant-Garde (ID: 1)
#    ├─ Novelty (ID: 6)
#    │  ├─ Sound Effects (ID: 16)
#    │  └─ Kid-Friendly (ID: 360)
#    ├─ Audio Collage (ID: 22)
#    ├─ Field Recordings (ID: 30)
#    ├─ Noise (ID: 32)
#    ├─ Electroacoustic (ID: 41)
#    ├─ Drone (ID: 47)
#    ├─ Unclassifiable (ID: 125)
#    ├─ Sound Poetry (ID: 186)
#    ├─ Sound Collage (ID: 224)
#    ├─ Musique Concrete (ID: 247)
#    ├─ Improv (ID: 250)
#    ├─ Minimalism (ID: 456)
#    └─ Sound Art (ID: 514)
#
# Instrumental (ID: 1235)
#
# ================================================================================
#
# ================================================================================
# STATISTIQUES DE L'ARBRE
# ================================================================================
#
# 📊 Répartition par niveau :
#   • Niveau 0 (ROOT)      :  13 genres
#   • Niveau 1 (enfants)   : 104 genres
#   • Niveau 2 (p-enfants) :  41 genres
#   • TOTAL                : 164 genres
#
# 🏆 Top 5 genres avec le plus d'enfants :
#   1. International        : 15 sous-genres
#   2. Rock                 : 15 sous-genres
#   3. Electronic           : 14 sous-genres
#   4. Experimental         : 14 sous-genres
#   5. Spoken               :  8 sous-genres
#
# ================================================================================
#
# 📊 Création de la visualisation graphique...
# ✓ Arbre visuel sauvegardé : .//genre_tree_complete.png
#
# ✅ Arbre des genres affiché avec succès !

# %%
L=["Instrumental","Experimental","Hip-Hop","Spoken","Folk","Electronic","Easy Listening","Rock","Pop","Classical","Jazz","Blues","International",]

# %%
tracks_non_vides = tracks[tracks['genre_top'].notna()]

print(f"Nombre total de tracks avec top_genre non vide : {len(tracks_non_vides)}")

# Sélectionner 100 lignes aléatoires
n_sample = min(100, len(tracks_non_vides))  # au cas où il y a moins de 100 lignes
sample_100 = tracks_non_vides.sample(n=n_sample, random_state=42)

# Vérifier combien sont dans L
dans_L = sample_100['genre_top'].isin(L).sum()
pourcentage = (dans_L / n_sample) * 100

print(f"\n{'='*50}")
print(f"Nombre de genres dans L : {dans_L}/{n_sample}")
print(f"Pourcentage : {pourcentage:.2f}%")
print(f"{'='*50}")

# Voir la distribution des genres dans l'échantillon
print("\n📊 Distribution des top 10 genres dans l'échantillon :")
print(sample_100['genre_top'].value_counts().head(10))

# Voir les genres uniques qui sont dans L
genres_presents = sample_100[sample_100['genre_top'].isin(L)]['genre_top'].unique()
print(f"\n✅ Genres de L présents : {list(genres_presents)}")

# Voir quelques exemples de genres qui ne sont PAS dans L
genres_absents = sample_100[~sample_100['genre_top'].isin(L)]['genre_top'].value_counts().head(5)
print(f"\n❌ Exemples de genres absents de L :")
print(genres_absents)
# Out:
# Nombre total de tracks avec top_genre non vide : 44633
#
# ==================================================
# Nombre de genres dans L : 97/100
# Pourcentage : 97.00%
# ==================================================
#
# 📊 Distribution des top 10 genres dans l'échantillon :
# genre_top
# Electronic             23
# Rock                   22
# Experimental           15
# Hip-Hop                 9
# Pop                     8
# Folk                    6
# International           6
# Instrumental            4
# Classical               3
# Old-Time / Historic     2
# Name: count, dtype: int64
#
# ✅ Genres de L présents : ['Pop', 'Folk', 'Experimental', 'Electronic', 'Rock', 'Instrumental', 'Hip-Hop', 'Spoken', 'International', 'Classical']
#
# ❌ Exemples de genres absents de L :
# genre_top
# Old-Time / Historic    2
# Country                1
# Name: count, dtype: int64

# %%
# Convertir les colonnes genres en listes
#tracks['genres'] = tracks['genres'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# Identifier les genres de niveau 0 (parents racines)
level_0_genres = genres[genres['genre_parent_id'].isna()]['genre_id'].tolist()


# Créer un dictionnaire pour mapper chaque genre à son parent de niveau 0
def get_level_0_parent(genre_id, genres_df):
    """Trouve le parent de niveau 0 d'un genre donné"""
    if genre_id in level_0_genres:
        return genre_id
    
    current_id = genre_id
    visited = set()
    
    while current_id not in level_0_genres and current_id is not None:
        if current_id in visited:  # Éviter les boucles infinies
            return None
        visited.add(current_id)
        
        parent_row = genres_df[genres_df['genre_id'] == current_id]
        if parent_row.empty:
            return None
        
        parent_id = parent_row['genre_parent_id'].values[0]
        if pd.isna(parent_id):
            return current_id
        current_id = int(parent_id)
    
    return current_id

# Créer le mapping genre_id -> parent_level_0
genre_to_level0 = {}
for genre_id in genres['genre_id']:
    genre_to_level0[genre_id] = get_level_0_parent(genre_id, genres)

# Fonction pour remplir genre_top manquant
def fill_missing_genre_top(row, genres_df, genre_to_level0_map, level_0_genres_list):
    """Remplit genre_top en trouvant le parent de niveau 0 avec le plus d'enfants/petits-enfants"""
    
    #if pd.notna(row['genre_top']):
        #return row['genre_top']
    
    if not row['genres'] or len(row['genres']) == 0:
        return np.nan
    
    # Compter les occurrences de chaque parent de niveau 0
    level_0_counts = {}
    
    for genre_id in row['genres']:
        parent_0 = genre_to_level0_map.get(genre_id)
        if parent_0 is not None and parent_0 in level_0_genres_list:
            level_0_counts[parent_0] = level_0_counts.get(parent_0, 0) + 1
    
    if not level_0_counts:
        return np.nan
    
    # Trouver le maximum
    max_count = max(level_0_counts.values())
    candidates = [k for k, v in level_0_counts.items() if v == max_count]
    
    # Si plusieurs candidats avec le même compte, choisir aléatoirement, Non on prend le premier 
    chosen_id = candidates[0]
    
    # Récupérer le titre du genre
    genre_title = genres_df[genres_df['genre_id'] == chosen_id]['genre_title'].values
    
    return genre_title[0] if len(genre_title) > 0 else np.nan

# Appliquer la fonction pour créer df_filled
df_filled = tracks.copy()
df_filled['genre_top'] = df_filled.apply(
    lambda row: fill_missing_genre_top(row, genres, genre_to_level0, level_0_genres),
    axis=1
)

# Afficher quelques statistiques
print(f"Valeurs manquantes avant: {tracks['genre_top'].isna().sum()}")
print(f"Valeurs manquantes après: {df_filled['genre_top'].isna().sum()}")
print(f"\nDistribution des genres top après remplissage:")
print(df_filled['genre_top'].value_counts())
# Out:
# Valeurs manquantes avant: 55362
# Valeurs manquantes après: 2222
#
# Distribution des genres top après remplissage:
# genre_top
# Experimental      23765
# Electronic        22971
# Rock              20187
# Folk               7340
# Pop                6715
# Hip-Hop            4409
# Easy Listening     3841
# International      2500
# Jazz               1907
# Classical          1866
# Blues              1402
# Spoken              608
# Instrumental        262
# Name: count, dtype: int64

# %%
tracks_filled = df_filled.to_csv('data/tracks_filled.tsv', sep='\t', index=False)
