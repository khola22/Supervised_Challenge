# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from collections.abc import Iterable
import ast
from helper import plot_missing_values, replace_titles_with_ids, replace_ids_with_titles, fill_top_genre, pca_group, make_pcs
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import math
import matplotlib.pyplot as plt
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# **Exploring the datasets**

# %%
# Explore different datasets
# Load the genres dataset
genres_path = os.path.join('data', 'genres.csv')
genres = pd.read_csv(genres_path)

echonest_path = os.path.join('data', 'echonest_features.tsv')
echonest = pd.read_csv(echonest_path, sep='\t')

tracks_path = os.path.join('data', 'tracks.tsv')
tracks = pd.read_csv(tracks_path, sep='\t')

spectral_path = os.path.join('data', 'spectral_features.tsv')
spectral = pd.read_csv(spectral_path, sep='\t')

genres_n_features = genres.shape[1] - 1  # Exclude the label column
genres_n_lines = genres.shape[0]

print(f"Genres dataset has {genres_n_lines} lines and {genres_n_features} features.")

echonest_n_features = echonest.shape[1] - 1
echonest_n_lines = echonest.shape[0]

print(f"Echonest dataset has {echonest_n_lines} lines and {echonest_n_features} features.")

tracks_n_features = tracks.shape[1] - 1
tracks_n_lines = tracks.shape[0]

print(f"Tracks dataset has {tracks_n_lines} lines and {tracks_n_features} features.")

spectral_n_features = spectral.shape[1] - 1
spectral_n_lines = spectral.shape[0]

print(f"Spectral dataset has {spectral_n_lines} lines and {spectral_n_features} features.")


# Explore the NA values 
na_counts = genres.isna().sum()
print("NA values in each column of genres dataset:")
print(na_counts[na_counts > 0])

na_counts_echonest = echonest.isna().sum()
print("NA values in each column of echonest dataset:")
print(na_counts_echonest[na_counts_echonest > 0])

na_counts_tracks = tracks.isna().sum()
print("NA values in each column of tracks dataset:")
print(na_counts_tracks[na_counts_tracks > 0])       

na_counts_spectral = spectral.isna().sum()
print("NA values in each column of spectral dataset:")
print(na_counts_spectral[na_counts_spectral > 0])

# Clearer plots for missing values: percent missing per column
datasets = {'Genres': genres, 'Echonest': echonest, 'Tracks': tracks, 'Spectral': spectral}
plt.figure(figsize=(14, 10))
for i, (name, df) in enumerate(datasets.items(), 1):
    plt.subplot(2, 2, i)
    # percent of missing values by column (0-100)
    na_pct = df.isna().mean() * 100
    na_pct = na_pct[na_pct > 0].sort_values(ascending=False)
    if na_pct.empty:
        plt.text(0.5, 0.5, 'No missing values', ha='center', va='center', fontsize=12)
        plt.title(f'{name}: 0 missing columns')
        plt.xlabel('')
        plt.yticks([])
    else:
        sns.barplot(x=na_pct.values, y=na_pct.index, palette='viridis')
        plt.xlabel('Percent missing (%)')
        plt.title(f'{name}: Missing values by column')
        # annotate bars with percent values
        for j, v in enumerate(na_pct.values):
            plt.text(v + 0.5, j, f'{v:.1f}%', va='center')
plt.suptitle('Percent Missing Values per Column', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# Genres dataset has 164 lines and 4 features.
# Echonest dataset has 11440 lines and 8 features.
# Tracks dataset has 99995 lines and 13 features.
# Spectral dataset has 99995 lines and 21 features.
# NA values in each column of genres dataset:
# genre_parent_id    13
# dtype: int64
# NA values in each column of echonest dataset:
# danceability     19
# speechiness     150
# valence          21
# dtype: int64
# NA values in each column of tracks dataset:
# album_title           911
# artist_latitude     59788
# artist_longitude    59788
# genre_top           55362
# title                   1
# dtype: int64
# NA values in each column of spectral dataset:
# Series([], dtype: int64)

# %%
# We substitute the titles in tracks datset with their ids in the genres dataset

genres_id = genres[['genre_id', 'genre_parent_id', 'genre_title']]

replace_titles_with_ids(tracks, 'genre_top', genres_id)

# Turn the values in genre_top to int 
tracks['genre_top'] = tracks['genre_top'].astype('Int64')

# save the tracks_id dataset 
tracks.to_csv('data/tracks_id.tsv', sep='\t', index=False)

# %%
# Now we re going to construct a dataset where genres are titles and not numbers 
# We can use the genres_id dataset to map back the genre_top ids to titles

tracks['genres'] = tracks['genres'].apply(ast.literal_eval)
tracks['genres_all'] = tracks['genres_all'].apply(ast.literal_eval)


# print the type of the values in 'genres' column
print(tracks['genres'].apply(type).unique())
print(tracks['genres_all'].apply(type).unique())

tracks_titles = replace_ids_with_titles(tracks.copy(), 'genre_top', genres_id)
tracks_titles = replace_ids_with_titles(tracks_titles, 'genres', genres_id)
tracks_titles = replace_ids_with_titles(tracks_titles, 'genres_all', genres_id)

tracks_titles.to_csv('data/tracks_titles.tsv', sep='\t', index=False)
# Out:
# [<class 'list'>]
# [<class 'list'>]

# %%
# test the function

# build the mapping, the parent should be a root node, see root_nodes
# We should keep going up the tree until we reach a root node
mapping_genre_parent = {}

parent_lookup = dict(zip(genres['genre_id'], genres['genre_parent_id']))

for gid in genres['genre_id']:
    current = gid
    parent = parent_lookup.get(current)

    while True:

        # Stop if parent is NaN
        if pd.isna(parent):
            break

        # Stop if parent points to itself (self-loop)
        if parent == current:
            break

        # Otherwise climb one level
        current = parent
        parent = parent_lookup.get(current)

    # current is now a root or self-parent
    mapping_genre_parent[gid] = current

# shape of unique values in mapping_genre_parent
print(len(set(mapping_genre_parent.values())))
# Out:
# 14

# %%
tracks_filled = fill_top_genre(tracks, mapping_genre_parent)
print(tracks_filled['genre_top'].isna().sum())
# Out:
# 0

# %%
# save the filled dataset
tracks_filled.to_csv('data/tracks_filled.tsv', sep='\t', index=False)

# %%
datasets = {'Genres': genres, 'Echonest': echonest, 'Tracks Filled': tracks_filled, 'Spectral': spectral}
plot_missing_values(datasets)

# %%
# Merging the datasets
# the 1st merge between tracks_filled and spectral_features on 'track_id'

# Remove the na values in tracks_filled in album_title and title features before merging
tracks_filled = tracks_filled.dropna(subset=['album_title', 'title'])

tracks_spectral = pd.merge(tracks_filled, spectral, on='track_id', how='left')

# The 2nd merge between tracks_spectral and echonest_features on 'track_id'
tracks_echonest = pd.merge(echonest, tracks_spectral, on='track_id', how='inner')

# %%
#Impute missing values in artist_latitude and artist_longitude
tracks_echonest['artist_location_unknown'] = np.where(
    tracks_echonest['artist_latitude'].isnull(), 
    1, 
    0
)
tracks_echonest['artist_latitude'] = tracks_echonest['artist_latitude'].fillna(0)
tracks_echonest['artist_longitude'] = tracks_echonest['artist_longitude'].fillna(0)
tracks_echonest.to_csv('data/tracks_echonest.tsv', sep='\t', index=False)

tracks_spectral['artist_location_unknown'] = np.where(
    tracks_spectral['artist_latitude'].isnull(), 
    1, 
    0
)
tracks_spectral['artist_latitude'] = tracks_spectral['artist_latitude'].fillna(0)
tracks_spectral['artist_longitude'] = tracks_spectral['artist_longitude'].fillna(0)
tracks_spectral.to_csv('data/tracks_spectral.tsv', sep='\t', index=False)

# %%
# Plot the missing values
datasets = {'Tracks_Echonest': tracks_echonest, 'Tracks_Spectral': tracks_spectral, 'Tracks_Filled': tracks_filled}

plot_missing_values(datasets)

# %%
# remove the lines with missing values in Tracks_Spectral
tracks_spectral = tracks_spectral.dropna()
tracks_spectral.to_csv('data/tracks_spectral.tsv', sep='\t', index=False)
# print the missing values after cleaning
print(tracks_spectral.isna().sum())
# Out:
# track_id                          0
# album_title                       0
# album_tracks                      0
# artist_latitude                   0
# artist_longitude                  0
# artist_name                       0
# duration                          0
# favorites                         0
# genre_top                         0
# genres                            0
# genres_all                        0
# interest                          0
# listens                           0
# title                             0
# spectral_bandwidth_kurtosis_01    0
# spectral_bandwidth_max_01         0
# spectral_bandwidth_mean_01        0
# spectral_bandwidth_median_01      0
# spectral_bandwidth_min_01         0
# spectral_bandwidth_skew_01        0
# spectral_bandwidth_std_01         0
# spectral_centroid_kurtosis_01     0
# spectral_centroid_max_01          0
# spectral_centroid_mean_01         0
# spectral_centroid_median_01       0
# spectral_centroid_min_01          0
# spectral_centroid_skew_01         0
# spectral_centroid_std_01          0
# spectral_rolloff_kurtosis_01      0
# spectral_rolloff_max_01           0
# spectral_rolloff_mean_01          0
# spectral_rolloff_median_01        0
# spectral_rolloff_min_01           0
# spectral_rolloff_skew_01          0
# spectral_rolloff_std_01           0
# artist_location_unknown           0
# dtype: int64

# %%
# Now we re going to construct datasets where genres are titles and not numbers
# datasets eith no mention of _title have ids for all genres, genres_all, genre_top

tracks_filled_titles = replace_ids_with_titles(tracks_filled.copy(), 'genre_top', genres_id)
tracks_filled_titles = replace_ids_with_titles(tracks_filled_titles, 'genres', genres_id)
tracks_filled_titles = replace_ids_with_titles(tracks_filled_titles, 'genres_all', genres_id)

tracks_filled_titles.to_csv('data/tracks_filled_titles.tsv', sep='\t', index=False)

tracks_echonest_titles = replace_ids_with_titles(tracks_echonest.copy(), 'genre_top', genres_id)
tracks_echonest_titles = replace_ids_with_titles(tracks_echonest_titles, 'genres', genres_id)
tracks_echonest_titles = replace_ids_with_titles(tracks_echonest_titles, 'genres_all', genres_id)

tracks_echonest_titles.to_csv('data/tracks_echonest_titles.tsv', sep='\t', index=False)

tracks_spectral_titles = replace_ids_with_titles(tracks_spectral.copy(), 'genre_top', genres_id)
tracks_spectral_titles = replace_ids_with_titles(tracks_spectral_titles, 'genres', genres_id)
tracks_spectral_titles = replace_ids_with_titles(tracks_spectral_titles, 'genres_all', genres_id)

tracks_spectral_titles.to_csv('data/tracks_spectral_titles.tsv', sep='\t', index=False)

# %%
numeric_cols = tracks_echonest.select_dtypes(include=['number']).columns

# Exclure les colonnes qui ne doivent PAS être utilisées (comme id)
numeric_cols = [c for c in numeric_cols if c not in ['track_id', 'id']]
print("Statistiques")

numeric_cols = echonest.select_dtypes(include=['number']).columns
numeric_cols = [c for c in numeric_cols if c not in ['track_id', 'id']]

print(tracks_echonest[numeric_cols].describe())
# Out:
# Statistiques
#        acousticness  danceability        energy  instrumentalness  \
# count  1.055200e+04  10533.000000  10552.000000      10552.000000
# mean   4.893387e-01      0.506814      0.541701          0.628827
# std    3.847772e-01      0.189796      0.274762          0.366886
# min    9.491000e-07      0.051435      0.000020          0.000000
# 25%    7.086072e-02      0.367386      0.330238          0.265446
# 50%    4.865710e-01      0.512027      0.554599          0.832358
# 75%    8.976159e-01      0.651317      0.774281          0.915124
# max    9.957965e-01      0.968645      0.999964          0.998016
#
#            liveness   speechiness         tempo       valence
# count  10552.000000  10407.000000  10552.000000  10531.000000
# mean       0.185582      0.098310    122.446269      0.449566
# std        0.153467      0.133854     34.928135      0.276186
# min        0.025916      0.022324      0.000000      0.008695
# 25%        0.100224      0.036824     95.746500      0.207358
# 50%        0.118614      0.049322    120.024000      0.433141
# 75%        0.213037      0.086434    143.960000      0.676782
# max        0.980330      0.966177    251.072000      0.999990

# %%
numeric_cols = echonest.select_dtypes(include=['number']).columns
numeric_cols = [c for c in numeric_cols if c not in ['track_id']]

n = len(numeric_cols)
rows = math.ceil(n/3)

fig, axes = plt.subplots(rows, 3, figsize=(15, 5*rows))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    echonest[col].hist(bins=40, ax=axes[i], alpha=0.7)
    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %%
numeric_cols = spectral.select_dtypes(include=['number']).columns
numeric_cols = [c for c in numeric_cols if c not in ['track_id', 'id']]

print("Statistiques (Spectral)")
print(spectral[numeric_cols].describe())
import math
fig, axes = plt.subplots(math.ceil(len(numeric_cols)/3), 3, figsize=(10, 10))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    spectral[col].hist(bins=40, ax=axes[i], alpha=0.7)
    axes[i].set_title(col)

plt.tight_layout()
plt.show()
# Out:
# Statistiques (Spectral)
#        spectral_bandwidth_kurtosis_01  spectral_bandwidth_max_01  \
# count                    99995.000000               99995.000000
# mean                         7.588260                3544.781941
# std                         28.517327                 384.217742
# min                         -1.961655                 469.536530
# 25%                         -0.074174                3361.957397
# 50%                          1.396075                3555.611572
# 75%                          5.662101                3703.081299
# max                       3143.452148                5495.584473
#
#        spectral_bandwidth_mean_01  spectral_bandwidth_median_01  \
# count                99995.000000                  99995.000000
# mean                  1408.089600                   1362.269289
# std                    463.258008                    509.942550
# min                     20.130140                      0.000000
# 25%                   1097.959961                   1006.116547
# 50%                   1395.607056                   1335.605225
# 75%                   1696.688660                   1678.246826
# max                   4079.638184                   4484.520019
#
#        spectral_bandwidth_min_01  spectral_bandwidth_skew_01  \
# count               99995.000000                99995.000000
# mean                  309.218658                    1.083953
# std                   322.982338                    1.847947
# min                     0.000000                  -22.545801
# 25%                     0.000000                    0.089207
# 50%                   285.374786                    0.706624
# 75%                   517.076721                    1.600140
# max                  3340.818115                   44.112976
#
#        spectral_bandwidth_std_01  spectral_centroid_kurtosis_01  \
# count               99995.000000                   99995.000000
# mean                  458.660662                      26.139062
# std                   178.582514                     104.120438
# min                    28.072506                      -1.947677
# 25%                   334.699280                       1.726195
# 50%                   441.644409                       6.131830
# 75%                   562.954926                      19.764040
# max                  2021.178833                    8638.212891
#
#        spectral_centroid_max_01  spectral_centroid_mean_01  ...  \
# count              99995.000000               99995.000000  ...
# mean                5640.080478                1177.314473  ...
# std                 1109.671918                 532.688615  ...
# min                  273.399445                  16.999098  ...
# 25%                 5432.561768                 810.262451  ...
# 50%                 5594.296875                1117.801636  ...
# 75%                 5916.375977                1457.341858  ...
# max                10844.517578                7974.038086  ...
#
#        spectral_centroid_min_01  spectral_centroid_skew_01  \
# count              99995.000000               99995.000000
# mean                 151.146755                   2.585898
# std                  204.261251                   2.943367
# min                    0.000000                 -13.857559
# 25%                    0.000000                   0.964591
# 50%                   95.085861                   1.751167
# 75%                  235.425262                   3.231028
# max                 5736.959961                  83.900589
#
#        spectral_centroid_std_01  spectral_rolloff_kurtosis_01  \
# count              99995.000000                  99995.000000
# mean                 603.301746                     20.095047
# std                  296.544970                    122.173648
# min                   12.398512                     -1.957410
# 25%                  390.402069                      0.152330
# 50%                  559.012756                      2.646303
# 75%                  765.466797                     10.985663
# max                 4156.937988                  12581.230469
#
#        spectral_rolloff_max_01  spectral_rolloff_mean_01  \
# count             99995.000000              99995.000000
# mean               9242.980201               2357.829761
# std                1032.626645               1149.569886
# min                 290.698242                 23.161127
# 25%                9259.277344               1530.490051
# 50%                9463.842773               2234.187988
# 75%                9673.791504               3009.756714
# max               11025.000000              10451.293945
#
#        spectral_rolloff_median_01  spectral_rolloff_min_01  \
# count                99995.000000             99995.000000
# mean                  2135.928474               169.388645
# std                   1284.889322               339.042187
# min                      0.000000                 0.000000
# 25%                   1195.092773                 0.000000
# 50%                   1905.688477                53.833008
# 75%                   2812.774658               193.798828
# max                  10949.633789              9496.142578
#
#        spectral_rolloff_skew_01  spectral_rolloff_std_01
# count              99995.000000             99995.000000
# mean                   2.027966              1290.258739
# std                    3.002037               572.302738
# min                  -25.933489                22.275246
# 25%                    0.509462               875.564850
# 50%                    1.261051              1241.191528
# 75%                    2.543224              1640.273438
# max                   95.301064              4833.974121
#
# [8 rows x 21 columns]

# %%
# Colonnes numériques uniquement
X = tracks_spectral.select_dtypes(include=[float, int])

# Calculer toutes les variances
variances = X.var()

# DataFrame trié par variance CROISSANTE (les plus faibles en 1er)
variance_df = pd.DataFrame({
    'feature': variances.index,
    'variance': variances.values
}).sort_values('variance', ascending=True)  # ← Les plus faibles d'abord

print("=== 15 FEATURES AUX PLUS FAIBLES VARIANCES ===")
print(variance_df.head(15))

# Graphique des 20 plus faibles
plt.figure(figsize=(12, 8))
plt.barh(range(20), variance_df.head(20)['variance'], color='red', alpha=0.7)
plt.yticks(range(20), variance_df.head(20)['feature'])
plt.xlabel('Variance')
plt.title('20 Features aux plus FAIBLES variances (à éliminer)')
plt.gca().invert_yaxis()  # Plus faibles en haut
plt.tight_layout()
plt.show()

# Seuil pour éliminer (exemple: variance < 1)
low_var_threshold = 1
low_var_features = variance_df[variance_df['variance'] < low_var_threshold]['feature'].tolist()
print(f"\nFeatures à éliminer (variance < {low_var_threshold}): {len(low_var_features)}")
print(low_var_features)
# Out:
# === 15 FEATURES AUX PLUS FAIBLES VARIANCES ===
#                            feature      variance
# 30         artist_location_unknown      0.240813
# 14      spectral_bandwidth_skew_01      3.442173
# 21       spectral_centroid_skew_01      8.717562
# 28        spectral_rolloff_skew_01      9.085672
# 5                        favorites    195.562324
# 2                  artist_latitude    526.600937
# 9   spectral_bandwidth_kurtosis_01    829.852514
# 1                     album_tracks   1630.066657
# 3                 artist_longitude   2036.018016
# 16   spectral_centroid_kurtosis_01  11014.029329
# 23    spectral_rolloff_kurtosis_01  15226.333590
# 6                        genre_top  29823.088474
# 15       spectral_bandwidth_std_01  31960.933888
# 20        spectral_centroid_min_01  41662.755288
# 4                         duration  80291.460846
# Features à éliminer (variance < 1): 1
# ['artist_location_unknown']

# %%
numeric_cols = tracks_spectral.select_dtypes(include=['number']).columns
numeric_cols = [c for c in numeric_cols if c not in ['track_id', 'id']]
corr_matrix = tracks_echonest[numeric_cols].corr()
print(corr_matrix)
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Matrice de corrélation - Features audio')
plt.tight_layout()
plt.show()
# Out:
#                                 album_tracks  artist_latitude  \
# album_tracks                        1.000000        -0.125698
# artist_latitude                    -0.125698         1.000000
# artist_longitude                    0.093433        -0.327597
# duration                           -0.094785        -0.001734
# favorites                          -0.031480        -0.003913
# genre_top                           0.129699        -0.047754
# interest                           -0.010075        -0.005183
# listens                            -0.012586        -0.026331
# spectral_bandwidth_kurtosis_01      0.029806        -0.131971
# spectral_bandwidth_max_01           0.031366         0.006077
# spectral_bandwidth_mean_01         -0.049074         0.075166
# spectral_bandwidth_median_01       -0.054981         0.072485
# spectral_bandwidth_min_01          -0.017971         0.030012
# spectral_bandwidth_skew_01          0.078372        -0.124626
# spectral_bandwidth_std_01           0.014398         0.082113
# spectral_centroid_kurtosis_01       0.036882        -0.120333
# spectral_centroid_max_01            0.016493        -0.010703
# spectral_centroid_mean_01          -0.051154         0.062437
# spectral_centroid_median_01        -0.066355         0.058998
# spectral_centroid_min_01           -0.010019        -0.008350
# spectral_centroid_skew_01           0.084129        -0.147327
# spectral_centroid_std_01            0.021015         0.064420
# spectral_rolloff_kurtosis_01        0.015117        -0.121159
# spectral_rolloff_max_01             0.035526        -0.017346
# spectral_rolloff_mean_01           -0.057174         0.069612
# spectral_rolloff_median_01         -0.068952         0.062256
# spectral_rolloff_min_01            -0.007708        -0.014776
# spectral_rolloff_skew_01            0.060771        -0.153391
# spectral_rolloff_std_01             0.018413         0.075494
# artist_location_unknown             0.145484        -0.823218
#
#                                 artist_longitude  duration  favorites  \
# album_tracks                            0.093433 -0.094785  -0.031480
# artist_latitude                        -0.327597 -0.001734  -0.003913
# artist_longitude                        1.000000 -0.007096  -0.022928
# duration                               -0.007096  1.000000   0.000903
# favorites                              -0.022928  0.000903   1.000000
# genre_top                               0.017616  0.014498   0.004708
# interest                               -0.020366 -0.007140   0.831551
# listens                                -0.011212 -0.006160   0.839972
# spectral_bandwidth_kurtosis_01          0.067211 -0.048977   0.024752
# spectral_bandwidth_max_01               0.059761  0.074662  -0.017752
# spectral_bandwidth_mean_01              0.005561 -0.021629  -0.027718
# spectral_bandwidth_median_01            0.016452 -0.027730  -0.029558
# spectral_bandwidth_min_01              -0.094822 -0.066507  -0.026970
# spectral_bandwidth_skew_01              0.030765 -0.011725   0.029909
# spectral_bandwidth_std_01               0.043405  0.054470   0.014815
# spectral_centroid_kurtosis_01           0.068214 -0.042950   0.074380
# spectral_centroid_max_01                0.057755  0.049565   0.002820
# spectral_centroid_mean_01               0.025921 -0.047505  -0.034469
# spectral_centroid_median_01             0.016966 -0.050893  -0.038940
# spectral_centroid_min_01               -0.074518 -0.089330  -0.027110
# spectral_centroid_skew_01               0.075136 -0.040752   0.055736
# spectral_centroid_std_01                0.084209 -0.002029   0.007128
# spectral_rolloff_kurtosis_01            0.071032 -0.045114   0.053056
# spectral_rolloff_max_01                 0.039442  0.034125  -0.021270
# spectral_rolloff_mean_01                0.021010 -0.043989  -0.029790
# spectral_rolloff_median_01              0.025353 -0.046889  -0.031731
# spectral_rolloff_min_01                -0.050631 -0.091838  -0.018636
# spectral_rolloff_skew_01                0.073843 -0.034152   0.048691
# spectral_rolloff_std_01                 0.059779  0.022977   0.007356
# artist_location_unknown                 0.412987 -0.001645  -0.003189
#
#                                 genre_top  interest   listens  \
# album_tracks                     0.129699 -0.010075 -0.012586
# artist_latitude                 -0.047754 -0.005183 -0.026331
# artist_longitude                 0.017616 -0.020366 -0.011212
# duration                         0.014498 -0.007140 -0.006160
# favorites                        0.004708  0.831551  0.839972
# genre_top                        1.000000  0.010909  0.033220
# interest                         0.010909  1.000000  0.854590
# listens                          0.033220  0.854590  1.000000
# spectral_bandwidth_kurtosis_01   0.006169  0.013860  0.043660
# spectral_bandwidth_max_01       -0.006710 -0.004228 -0.003592
# spectral_bandwidth_mean_01      -0.065243 -0.025380 -0.045970
# spectral_bandwidth_median_01    -0.061101 -0.028500 -0.048091
# spectral_bandwidth_min_01       -0.040081 -0.024719 -0.042948
# spectral_bandwidth_skew_01       0.031311  0.021659  0.051118
# spectral_bandwidth_std_01       -0.015986  0.025574  0.023197
# spectral_centroid_kurtosis_01    0.011104  0.030580  0.089934
# spectral_centroid_max_01         0.012392  0.005022  0.016558
# spectral_centroid_mean_01       -0.063793 -0.029610 -0.046490
# spectral_centroid_median_01     -0.059809 -0.035006 -0.052684
# spectral_centroid_min_01        -0.045535 -0.024215 -0.038889
# spectral_centroid_skew_01        0.025598  0.029858  0.073985
# spectral_centroid_std_01        -0.030028  0.014081  0.016208
# spectral_rolloff_kurtosis_01     0.002944  0.018437  0.059299
# spectral_rolloff_max_01          0.005348 -0.010154 -0.004054
# spectral_rolloff_mean_01        -0.064951 -0.027040 -0.043814
# spectral_rolloff_median_01      -0.057319 -0.031228 -0.045694
# spectral_rolloff_min_01         -0.039238 -0.017688 -0.028099
# spectral_rolloff_skew_01         0.023739  0.025338  0.062230
# spectral_rolloff_std_01         -0.034205  0.016398  0.014333
# artist_location_unknown         -0.001931 -0.008856  0.009772
#
#                                 spectral_bandwidth_kurtosis_01  \
# album_tracks                                          0.029806
# artist_latitude                                      -0.131971
# artist_longitude                                      0.067211
# duration                                             -0.048977
# favorites                                             0.024752
# genre_top                                             0.006169
# interest                                              0.013860
# listens                                               0.043660
# spectral_bandwidth_kurtosis_01                        1.000000
# spectral_bandwidth_max_01                            -0.014189
# spectral_bandwidth_mean_01                           -0.367418
# spectral_bandwidth_median_01                         -0.335068
# spectral_bandwidth_min_01                            -0.042694
# spectral_bandwidth_skew_01                            0.769905
# spectral_bandwidth_std_01                            -0.347469
# spectral_centroid_kurtosis_01                         0.721515
# spectral_centroid_max_01                              0.001556
# spectral_centroid_mean_01                            -0.227746
# spectral_centroid_median_01                          -0.181149
# spectral_centroid_min_01                              0.082704
# spectral_centroid_skew_01                             0.658479
# spectral_centroid_std_01                             -0.292746
# spectral_rolloff_kurtosis_01                          0.683044
# spectral_rolloff_max_01                               0.043529
# spectral_rolloff_mean_01                             -0.253821
# spectral_rolloff_median_01                           -0.195879
# spectral_rolloff_min_01                               0.094098
# spectral_rolloff_skew_01                              0.699783
# spectral_rolloff_std_01                              -0.347882
# artist_location_unknown                               0.143008
#
#                                 spectral_bandwidth_max_01  ...  \
# album_tracks                                     0.031366  ...
# artist_latitude                                  0.006077  ...
# artist_longitude                                 0.059761  ...
# duration                                         0.074662  ...
# favorites                                       -0.017752  ...
# genre_top                                       -0.006710  ...
# interest                                        -0.004228  ...
# listens                                         -0.003592  ...
# spectral_bandwidth_kurtosis_01                  -0.014189  ...
# spectral_bandwidth_max_01                        1.000000  ...
# spectral_bandwidth_mean_01                       0.150562  ...
# spectral_bandwidth_median_01                     0.118307  ...
# spectral_bandwidth_min_01                       -0.173404  ...
# spectral_bandwidth_skew_01                       0.041566  ...
# spectral_bandwidth_std_01                        0.384578  ...
# spectral_centroid_kurtosis_01                    0.015411  ...
# spectral_centroid_max_01                         0.736446  ...
# spectral_centroid_mean_01                        0.085210  ...
# spectral_centroid_median_01                      0.020846  ...
# spectral_centroid_min_01                        -0.202611  ...
# spectral_centroid_skew_01                        0.131019  ...
# spectral_centroid_std_01                         0.394259  ...
# spectral_rolloff_kurtosis_01                    -0.035970  ...
# spectral_rolloff_max_01                          0.746820  ...
# spectral_rolloff_mean_01                         0.080545  ...
# spectral_rolloff_median_01                       0.024086  ...
# spectral_rolloff_min_01                         -0.173468  ...
# spectral_rolloff_skew_01                         0.026577  ...
# spectral_rolloff_std_01                          0.383389  ...
# artist_location_unknown                         -0.003406  ...
#
#                                 spectral_centroid_skew_01  \
# album_tracks                                     0.084129
# artist_latitude                                 -0.147327
# artist_longitude                                 0.075136
# duration                                        -0.040752
# favorites                                        0.055736
# genre_top                                        0.025598
# interest                                         0.029858
# listens                                          0.073985
# spectral_bandwidth_kurtosis_01                   0.658479
# spectral_bandwidth_max_01                        0.131019
# spectral_bandwidth_mean_01                      -0.577947
# spectral_bandwidth_median_01                    -0.568357
# spectral_bandwidth_min_01                       -0.048859
# spectral_bandwidth_skew_01                       0.814233
# spectral_bandwidth_std_01                       -0.315696
# spectral_centroid_kurtosis_01                    0.852985
# spectral_centroid_max_01                         0.177024
# spectral_centroid_mean_01                       -0.511869
# spectral_centroid_median_01                     -0.483330
# spectral_centroid_min_01                         0.074836
# spectral_centroid_skew_01                        1.000000
# spectral_centroid_std_01                        -0.323719
# spectral_rolloff_kurtosis_01                     0.689759
# spectral_rolloff_max_01                          0.160036
# spectral_rolloff_mean_01                        -0.540062
# spectral_rolloff_median_01                      -0.492548
# spectral_rolloff_min_01                          0.079196
# spectral_rolloff_skew_01                         0.918384
# spectral_rolloff_std_01                         -0.389462
# artist_location_unknown                          0.164300
#
#                                 spectral_centroid_std_01  \
# album_tracks                                    0.021015
# artist_latitude                                 0.064420
# artist_longitude                                0.084209
# duration                                       -0.002029
# favorites                                       0.007128
# genre_top                                      -0.030028
# interest                                        0.014081
# listens                                         0.016208
# spectral_bandwidth_kurtosis_01                 -0.292746
# spectral_bandwidth_max_01                       0.394259
# spectral_bandwidth_mean_01                      0.556418
# spectral_bandwidth_median_01                    0.517182
# spectral_bandwidth_min_01                      -0.117802
# spectral_bandwidth_skew_01                     -0.377457
# spectral_bandwidth_std_01                       0.785625
# spectral_centroid_kurtosis_01                  -0.316807
# spectral_centroid_max_01                        0.429733
# spectral_centroid_mean_01                       0.531560
# spectral_centroid_median_01                     0.363183
# spectral_centroid_min_01                       -0.227235
# spectral_centroid_skew_01                      -0.323719
# spectral_centroid_std_01                        1.000000
# spectral_rolloff_kurtosis_01                   -0.292232
# spectral_rolloff_max_01                         0.270717
# spectral_rolloff_mean_01                        0.522715
# spectral_rolloff_median_01                      0.400950
# spectral_rolloff_min_01                        -0.215112
# spectral_rolloff_skew_01                       -0.406146
# spectral_rolloff_std_01                         0.928531
# artist_location_unknown                        -0.049485
#
#                                 spectral_rolloff_kurtosis_01  \
# album_tracks                                        0.015117
# artist_latitude                                    -0.121159
# artist_longitude                                    0.071032
# duration                                           -0.045114
# favorites                                           0.053056
# genre_top                                           0.002944
# interest                                            0.018437
# listens                                             0.059299
# spectral_bandwidth_kurtosis_01                      0.683044
# spectral_bandwidth_max_01                          -0.035970
# spectral_bandwidth_mean_01                         -0.362781
# spectral_bandwidth_median_01                       -0.334725
# spectral_bandwidth_min_01                          -0.020264
# spectral_bandwidth_skew_01                          0.574164
# spectral_bandwidth_std_01                          -0.296135
# spectral_centroid_kurtosis_01                       0.862814
# spectral_centroid_max_01                           -0.015874
# spectral_centroid_mean_01                          -0.245974
# spectral_centroid_median_01                        -0.204094
# spectral_centroid_min_01                            0.125430
# spectral_centroid_skew_01                           0.689759
# spectral_centroid_std_01                           -0.292232
# spectral_rolloff_kurtosis_01                        1.000000
# spectral_rolloff_max_01                             0.031825
# spectral_rolloff_mean_01                           -0.279089
# spectral_rolloff_median_01                         -0.224004
# spectral_rolloff_min_01                             0.125431
# spectral_rolloff_skew_01                            0.831697
# spectral_rolloff_std_01                            -0.340529
# artist_location_unknown                             0.141522
#
#                                 spectral_rolloff_max_01  \
# album_tracks                                   0.035526
# artist_latitude                               -0.017346
# artist_longitude                               0.039442
# duration                                       0.034125
# favorites                                     -0.021270
# genre_top                                      0.005348
# interest                                      -0.010154
# listens                                       -0.004054
# spectral_bandwidth_kurtosis_01                 0.043529
# spectral_bandwidth_max_01                      0.746820
# spectral_bandwidth_mean_01                     0.087733
# spectral_bandwidth_median_01                   0.071425
# spectral_bandwidth_min_01                     -0.245385
# spectral_bandwidth_skew_01                     0.051956
# spectral_bandwidth_std_01                      0.241686
# spectral_centroid_kurtosis_01                  0.076087
# spectral_centroid_max_01                       0.787397
# spectral_centroid_mean_01                      0.073953
# spectral_centroid_median_01                    0.032130
# spectral_centroid_min_01                      -0.214274
# spectral_centroid_skew_01                      0.160036
# spectral_centroid_std_01                       0.270717
# spectral_rolloff_kurtosis_01                   0.031825
# spectral_rolloff_max_01                        1.000000
# spectral_rolloff_mean_01                       0.060975
# spectral_rolloff_median_01                     0.027018
# spectral_rolloff_min_01                       -0.147658
# spectral_rolloff_skew_01                       0.075321
# spectral_rolloff_std_01                        0.244744
# artist_location_unknown                        0.009022
#
#                                 spectral_rolloff_mean_01  \
# album_tracks                                   -0.057174
# artist_latitude                                 0.069612
# artist_longitude                                0.021010
# duration                                       -0.043989
# favorites                                      -0.029790
# genre_top                                      -0.064951
# interest                                       -0.027040
# listens                                        -0.043814
# spectral_bandwidth_kurtosis_01                 -0.253821
# spectral_bandwidth_max_01                       0.080545
# spectral_bandwidth_mean_01                      0.931358
# spectral_bandwidth_median_01                    0.933550
# spectral_bandwidth_min_01                       0.217237
# spectral_bandwidth_skew_01                     -0.586005
# spectral_bandwidth_std_01                       0.223517
# spectral_centroid_kurtosis_01                  -0.337717
# spectral_centroid_max_01                        0.131201
# spectral_centroid_mean_01                       0.980794
# spectral_centroid_median_01                     0.951842
# spectral_centroid_min_01                        0.144027
# spectral_centroid_skew_01                      -0.540062
# spectral_centroid_std_01                        0.522715
# spectral_rolloff_kurtosis_01                   -0.279089
# spectral_rolloff_max_01                         0.060975
# spectral_rolloff_mean_01                        1.000000
# spectral_rolloff_median_01                      0.966154
# spectral_rolloff_min_01                         0.144915
# spectral_rolloff_skew_01                       -0.569733
# spectral_rolloff_std_01                         0.465340
# artist_location_unknown                        -0.062254
#
#                                 spectral_rolloff_median_01  \
# album_tracks                                     -0.068952
# artist_latitude                                   0.062256
# artist_longitude                                  0.025353
# duration                                         -0.046889
# favorites                                        -0.031731
# genre_top                                        -0.057319
# interest                                         -0.031228
# listens                                          -0.045694
# spectral_bandwidth_kurtosis_01                   -0.195879
# spectral_bandwidth_max_01                         0.024086
# spectral_bandwidth_mean_01                        0.867068
# spectral_bandwidth_median_01                      0.903459
# spectral_bandwidth_min_01                         0.207976
# spectral_bandwidth_skew_01                       -0.545705
# spectral_bandwidth_std_01                         0.080601
# spectral_centroid_kurtosis_01                    -0.277943
# spectral_centroid_max_01                          0.085036
# spectral_centroid_mean_01                         0.948135
# spectral_centroid_median_01                       0.969663
# spectral_centroid_min_01                          0.149675
# spectral_centroid_skew_01                        -0.492548
# spectral_centroid_std_01                          0.400950
# spectral_rolloff_kurtosis_01                     -0.224004
# spectral_rolloff_max_01                           0.027018
# spectral_rolloff_mean_01                          0.966154
# spectral_rolloff_median_01                        1.000000
# spectral_rolloff_min_01                           0.149438
# spectral_rolloff_skew_01                         -0.516156
# spectral_rolloff_std_01                           0.319718
# artist_location_unknown                          -0.054162
#
#                                 spectral_rolloff_min_01  \
# album_tracks                                  -0.007708
# artist_latitude                               -0.014776
# artist_longitude                              -0.050631
# duration                                      -0.091838
# favorites                                     -0.018636
# genre_top                                     -0.039238
# interest                                      -0.017688
# listens                                       -0.028099
# spectral_bandwidth_kurtosis_01                 0.094098
# spectral_bandwidth_max_01                     -0.173468
# spectral_bandwidth_mean_01                     0.094128
# spectral_bandwidth_median_01                   0.089074
# spectral_bandwidth_min_01                      0.697301
# spectral_bandwidth_skew_01                     0.126931
# spectral_bandwidth_std_01                     -0.300476
# spectral_centroid_kurtosis_01                  0.088854
# spectral_centroid_max_01                      -0.139337
# spectral_centroid_mean_01                      0.165155
# spectral_centroid_median_01                    0.190716
# spectral_centroid_min_01                       0.899496
# spectral_centroid_skew_01                      0.079196
# spectral_centroid_std_01                      -0.215112
# spectral_rolloff_kurtosis_01                   0.125431
# spectral_rolloff_max_01                       -0.147658
# spectral_rolloff_mean_01                       0.144915
# spectral_rolloff_median_01                     0.149438
# spectral_rolloff_min_01                        1.000000
# spectral_rolloff_skew_01                       0.127257
# spectral_rolloff_std_01                       -0.252763
# artist_location_unknown                        0.025970
#
#                                 spectral_rolloff_skew_01  \
# album_tracks                                    0.060771
# artist_latitude                                -0.153391
# artist_longitude                                0.073843
# duration                                       -0.034152
# favorites                                       0.048691
# genre_top                                       0.023739
# interest                                        0.025338
# listens                                         0.062230
# spectral_bandwidth_kurtosis_01                  0.699783
# spectral_bandwidth_max_01                       0.026577
# spectral_bandwidth_mean_01                     -0.625881
# spectral_bandwidth_median_01                   -0.613796
# spectral_bandwidth_min_01                      -0.045463
# spectral_bandwidth_skew_01                      0.837449
# spectral_bandwidth_std_01                      -0.337398
# spectral_centroid_kurtosis_01                   0.836900
# spectral_centroid_max_01                        0.022501
# spectral_centroid_mean_01                      -0.525094
# spectral_centroid_median_01                    -0.485909
# spectral_centroid_min_01                        0.119295
# spectral_centroid_skew_01                       0.918384
# spectral_centroid_std_01                       -0.406146
# spectral_rolloff_kurtosis_01                    0.831697
# spectral_rolloff_max_01                         0.075321
# spectral_rolloff_mean_01                       -0.569733
# spectral_rolloff_median_01                     -0.516156
# spectral_rolloff_min_01                         0.127257
# spectral_rolloff_skew_01                        1.000000
# spectral_rolloff_std_01                        -0.452976
# artist_location_unknown                         0.169625
#
#                                 spectral_rolloff_std_01  \
# album_tracks                                   0.018413
# artist_latitude                                0.075494
# artist_longitude                               0.059779
# duration                                       0.022977
# favorites                                      0.007356
# genre_top                                     -0.034205
# interest                                       0.016398
# listens                                        0.014333
# spectral_bandwidth_kurtosis_01                -0.347882
# spectral_bandwidth_max_01                      0.383389
# spectral_bandwidth_mean_01                     0.570249
# spectral_bandwidth_median_01                   0.518970
# spectral_bandwidth_min_01                     -0.138773
# spectral_bandwidth_skew_01                    -0.417640
# spectral_bandwidth_std_01                      0.903233
# spectral_centroid_kurtosis_01                 -0.365339
# spectral_centroid_max_01                       0.338136
# spectral_centroid_mean_01                      0.441935
# spectral_centroid_median_01                    0.276520
# spectral_centroid_min_01                      -0.254767
# spectral_centroid_skew_01                     -0.389462
# spectral_centroid_std_01                       0.928531
# spectral_rolloff_kurtosis_01                  -0.340529
# spectral_rolloff_max_01                        0.244744
# spectral_rolloff_mean_01                       0.465340
# spectral_rolloff_median_01                     0.319718
# spectral_rolloff_min_01                       -0.252763
# spectral_rolloff_skew_01                      -0.452976
# spectral_rolloff_std_01                        1.000000
# artist_location_unknown                       -0.068575
#
#                                 artist_location_unknown
# album_tracks                                   0.145484
# artist_latitude                               -0.823218
# artist_longitude                               0.412987
# duration                                      -0.001645
# favorites                                     -0.003189
# genre_top                                     -0.001931
# interest                                      -0.008856
# listens                                        0.009772
# spectral_bandwidth_kurtosis_01                 0.143008
# spectral_bandwidth_max_01                     -0.003406
# spectral_bandwidth_mean_01                    -0.077796
# spectral_bandwidth_median_01                  -0.073279
# spectral_bandwidth_min_01                     -0.020553
# spectral_bandwidth_skew_01                     0.132149
# spectral_bandwidth_std_01                     -0.079962
# spectral_centroid_kurtosis_01                  0.141683
# spectral_centroid_max_01                       0.011988
# spectral_centroid_mean_01                     -0.054000
# spectral_centroid_median_01                   -0.052846
# spectral_centroid_min_01                       0.019425
# spectral_centroid_skew_01                      0.164300
# spectral_centroid_std_01                      -0.049485
# spectral_rolloff_kurtosis_01                   0.141522
# spectral_rolloff_max_01                        0.009022
# spectral_rolloff_mean_01                      -0.062254
# spectral_rolloff_median_01                    -0.054162
# spectral_rolloff_min_01                        0.025970
# spectral_rolloff_skew_01                       0.169625
# spectral_rolloff_std_01                       -0.068575
# artist_location_unknown                        1.000000
#
# [30 rows x 30 columns]

# %%
#group avec correlation entre élts > 0.98
group1=['spectral_bandwidth_median_01','spectral_bandwidth_mean_01']
group2=['spectral_centroid_median_01','spectral_centroid_mean_01']
group3=['spectral_rolloff_median_01','spectral_rolloff_mean_01']
#on supprime les variables redondantes 
to_drop = [
    'spectral_bandwidth_median_01',
    'spectral_centroid_median_01',
    'spectral_rolloff_median_01'  
]
tracks_spectral_reduced = tracks_spectral.drop(columns=to_drop)
#group avec correlation entre élts > 0.85
group4=['spectral_rolloff_mean_01','spectral_bandwidth_mean_01','spectral_centroid_mean_01']
group5=['interest','listens','favorites']
#goup avec correllation >0.65
group6=['spectral_bandwidth_skew_01','spectral_centroid_kurtosis_01','spectral_bandwidth_kurtosis_01','spectral_centroid_skew_01','spectral_rolloff_skew_01',
        'spectral_rolloff_kurtosis_01']

# %%
# Appliquer PCA sur chaque groupe et afficher variance
pca_group(tracks_spectral_reduced, group4, "4 (moyennes spectrales)")
pca_group(tracks_spectral_reduced, group5, "5 (popularité)")
pca_group(tracks_spectral_reduced, group6, "6 (skew/kurtosis)")
# Out:
# Groupe 4 (moyennes spectrales) (3 variables)
# Variance expliquée par composante : [0.95413426 0.04030683 0.00555891]
# Variance cumulée : [0.95413426 0.99444109 1.        ]
#
# Groupe 5 (popularité) (3 variables)
# Variance expliquée par composante : [0.88420548 0.05947391 0.05632061]
# Variance cumulée : [0.88420548 0.94367939 1.        ]
#
# Groupe 6 (skew/kurtosis) (6 variables)
# Variance expliquée par composante : [0.70772249 0.13650326 0.09028994 0.0425328  0.01720451 0.005747  ]
# Variance cumulée : [0.70772249 0.84422575 0.93451569 0.97704849 0.994253   1.        ]

# %%
# group4 → 1 PC
tracks_spectral_reduced = make_pcs(tracks_spectral_reduced, group4, 1, 'g4')

# group5 → 1 PC
tracks_spectral_reduced = make_pcs(tracks_spectral_reduced, group5, 1, 'g5')

# group6 → 3 PC
tracks_spectral_reduced = make_pcs(tracks_spectral_reduced, group6, 3, 'g6')

# puis on supprime les colonnes originales de ces groupes
tracks_spectral_reduced = tracks_spectral_reduced.drop(columns=group4+group5+group6)

# %%
tracks_spectral_reduced.to_csv('data/tracks_spectral_reduced.csv')

# %%
tracks_spectral_reduced.columns
# Out:
# Index(['track_id', 'album_title', 'album_tracks', 'artist_latitude',
#        'artist_longitude', 'artist_name', 'duration', 'genre_top', 'genres',
#        'genres_all', 'title', 'spectral_bandwidth_max_01',
#        'spectral_bandwidth_min_01', 'spectral_bandwidth_std_01',
#        'spectral_centroid_max_01', 'spectral_centroid_min_01',
#        'spectral_centroid_std_01', 'spectral_rolloff_max_01',
#        'spectral_rolloff_min_01', 'spectral_rolloff_std_01',
#        'artist_location_unknown', 'g4_pc1', 'g5_pc1', 'g6_pc1', 'g6_pc2',
#        'g6_pc3'],
#       dtype='object')
